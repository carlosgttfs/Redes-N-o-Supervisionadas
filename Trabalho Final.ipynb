# %%
# Este ambiente Python 3 vem com muitas bibliotecas de análise úteis instaladas
# Ele é definido pela imagem Docker kaggle/python: https://github.com/kaggle/docker-python
# Por exemplo, aqui estão vários pacotes úteis para carregar

import numpy as np # álgebra linear
import pandas as pd # processamento de dados, E/S de arquivos CSV (por exemplo, pd.read_csv)


import numpy as np
from sklearn.cluster import KMeans

from minisom import MiniSom  

import matplotlib.pyplot as plt
# %matplotlib inline

# Os arquivos de dados de entrada estão disponíveis no diretório somente leitura "../input/"
# Por exemplo, executar isso (clicando em executar ou pressionando Shift+Enter) listará todos os arquivos no diretório de entrada

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Você pode escrever até 20GB no diretório atual (/kaggle/working/) que é preservado como saída quando você cria uma versão usando "Salvar & Executar Tudo"
# Você também pode escrever arquivos temporários em /kaggle/temp/, mas eles não serão salvos fora da sessão atual

# %% [markdown]
# ## Introdução
#
# Neste notebook, demonstraremos como usar o minisom para fazer clustering de topologia linear
#
# Por favor, vote positivamente neste notebook se achar útil :)
#
# Jonathan Kristanto &copy; Maio 2021

# %% [markdown]
# ## Importar Dados

# %%
DATA_DIR = './dataset/Mall_Customers.csv'
df = pd.read_csv(DATA_DIR)
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Seleção de Características
#
# Veremos quais combinações de características podem ser agrupadas

# %% [markdown]
# ### Distribuição de Dados de Idade e Pontuação de Gastos
#
# Resultado: Nenhum cluster aparente detectado

# %%
age = df['Age'].tolist()
spending_score = df['Spending Score (1-100)'].tolist()
annual_income = df['Annual Income (k$)'].tolist()
fig = plt.figure(figsize=(6,6))
plt.scatter(age, spending_score)
plt.suptitle("Gráfico de Dispersão de Idade e Pontuação de Gastos")
plt.xlabel("Idade")
plt.ylabel("Pontuação de Gastos")
plt.show()

# %% [markdown]
# ### Distribuição de Dados de Idade e Renda Anual
#
# Resultado: Nenhum cluster aparente detectado

# %%
age = df['Age'].tolist()
annual_income = df['Annual Income (k$)'].tolist()
fig = plt.figure(figsize=(6,6))
plt.scatter(age, annual_income)
plt.suptitle("Gráfico de Dispersão de Idade e Renda Anual")
plt.xlabel("Idade")
plt.ylabel("Renda Anual (k$)")
plt.show()

# %% [markdown]
# ### Distribuição de Dados de Renda Anual e Pontuação de Gastos
#
# **Resultado: Existem 5 clusters detectados**

# %%
annual_income = df['Annual Income (k$)'].tolist()
spending_score = df['Spending Score (1-100)'].tolist()
fig = plt.figure(figsize=(6,6))
plt.scatter(annual_income, spending_score)
plt.suptitle("Gráfico de Dispersão de Renda Anual & Pontuação de Gastos")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.show()

# %% [markdown]
# ## Limpar & Transformar Dados

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Selecionar Renda Anual e Pontuação de Gastos como nossas características
features = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# Transformar características em lista
data_all = features.values
data_all.shape

from sklearn.model_selection import train_test_split

# Divisão em treinamento e validação
data_train, data_val = train_test_split(data_all, test_size=0.5, random_state=42)

from sklearn.preprocessing import MinMaxScaler

# Criar o MinMaxScaler
scaler = MinMaxScaler()

# Ajustar e transformar os dados
data_train_normalized = scaler.fit_transform(data_train)
data_all_normalized = scaler.transform(data_all)
data_val_normalized = scaler.transform(data_val)

# %%
annual_income = data_train[:,0]
spending_score = data_train[:,1]
fig = plt.figure(figsize=(6,6))
plt.scatter(annual_income, spending_score)
plt.suptitle("Gráfico de Dispersão de Renda Anual & Pontuação de Gastos")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.show()

# %%
annual_income = data_val[:,0]
spending_score = data_val[:,1]
fig = plt.figure(figsize=(6,6))
plt.scatter(annual_income, spending_score)
plt.suptitle("Gráfico de Dispersão de Renda Anual & Pontuação de Gastos")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.show()

# %% [markdown]
# # Parâmetros gerais do dataset

# %%
global_centroid_all = np.mean(data_all_normalized, axis=0) # Calcular o centróide global
F_0_all = np.sum(np.linalg.norm(data_all_normalized - global_centroid_all, axis=1)**2) # Calcular F_0 (dispersão total)
n_0_all = data_all_normalized.shape[0] # Número total de pontos
sigma_0_all = np.sqrt(F_0_all / n_0_all) # Calcular o desvio padrão total

print(f"Número total de elementos (n_0): {n_0_all}")
print(f"Baricentro Global (m_0): ", global_centroid_all)
print(f"Dispersão total (F_0): {F_0_all:.2f}")
print(f"Desvio padrão total (\\sigma_0): {sigma_0_all:.2f}")

print('Treinamento')
global_centroid_train = np.mean(data_train_normalized, axis=0) # Calcular o centróide global
F_0_train = np.sum(np.linalg.norm(data_train_normalized - global_centroid_train, axis=1)**2) # Calcular F_0 (dispersão total)
n_0_train = data_train_normalized.shape[0] # Número total de pontos
sigma_0_train = np.sqrt(F_0_train / n_0_train) # Calcular o desvio padrão total

print(f"Número total de elementos (n_0): {n_0_train}")
print(f"Baricentro Global (m_0): ", global_centroid_train)
print(f"Dispersão total (F_0): {F_0_train:.2f}")
print(f"Desvio padrão total (\\sigma_0): {sigma_0_train:.2f}")

print('Validação')
global_centroid_val = np.mean(data_val_normalized, axis=0) # Calcular o centróide global
F_0_val = np.sum(np.linalg.norm(data_val_normalized - global_centroid_val, axis=1)**2) # Calcular F_0 (dispersão total)
n_0_val = data_val_normalized.shape[0] # Número total de pontos
sigma_0_val = np.sqrt(F_0_val / n_0_val) # Calcular o desvio padrão total

print(f"Número total de elementos (n_0): {n_0_val}")
print(f"Baricentro Global (m_0): ", global_centroid_val)
print(f"Dispersão total (F_0): {F_0_val:.2f}")
print(f"Desvio padrão total (\\sigma_0): {sigma_0_val:.2f}")
# Out:
# Número total de elementos (n_0): 200
# Baricentro Global (m_0):  [0.37344262 0.5125    ]
# Dispersão total (F_0): 23.62
# Desvio padrão total (\sigma_0): 0.34
# Treinamento
# Número total de elementos (n_0): 100
# Baricentro Global (m_0):  [0.37901639 0.521875  ]
# Dispersão total (F_0): 12.14
# Desvio padrão total (\sigma_0): 0.35
# Validação
# Número total de elementos (n_0): 100
# Baricentro Global (m_0):  [0.36786885 0.503125  ]
# Dispersão total (F_0): 11.45
# Desvio padrão total (\sigma_0): 0.34

# %% [markdown]
# # Treinamento dos Modelos

# %% [markdown]
# ## K-means

# %%
import numpy as np
from sklearn.cluster import KMeans

# Função para calcular a dispersão intra-cluster F_j
def calcular_dispersaointra(cluster_points, centroid):
    return np.sum(np.linalg.norm(cluster_points - centroid, axis=1)**2)

# Função para calcular o diâmetro máximo do cluster
def calcular_diametro(cluster_points):
    max_distance = 0
    for i in range(len(cluster_points)):
        for k in range(i + 1, len(cluster_points)):
            dist = np.linalg.norm(cluster_points[i] - cluster_points[k])
            max_distance = max(max_distance, dist)
    return max_distance

# Função para calcular a variância intra-cluster
def calcular_variancia_intra(cluster_points, centroid):
    return np.mean(np.linalg.norm(cluster_points - centroid, axis=1)**2)

# Função para calcular o desvio padrão intra-cluster
def calcular_desvio_padrao_intra(variancia_intra):
    return np.sqrt(variancia_intra)

# Função para calcular a dispersão inter-cluster F_out
def calcular_dispersaointer(centroids, data, labels, n_clusters):
    F_out = 0
    global_centroid = np.mean(centroids, axis=0)  # Centróide global (média dos centróides dos clusters)
    for j in range(n_clusters):
        cluster_points = data[labels == j]  # Dados no cluster j
        n_j = len(cluster_points)           # Número de pontos no cluster j
        centroid_j = centroids[j]           # Centróide do cluster j
        F_out += n_j * np.linalg.norm(centroid_j - global_centroid)**2
    return F_out

# Função principal para calcular as métricas do KMeans
def calcular_metricas_cluster_kmeans(data, max_clusters=10):
    # Inicialização das listas para armazenar os resultados
    F_out_values = []
    F_in_values = []
    n_cluster_points_values = []
    centroid_values = []
    max_distance_values = []
    variancia_intra_values = []
    desvio_padrao_intra_values = []

    # Loop para diferentes números de clusters
    for n_clusters in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=n_clusters, random_state=0)
        kmeans.fit(data)
        
        # Obter os rótulos e centróides
        labels = kmeans.labels_
        centroids = kmeans.cluster_centers_

        # Calcular F_j para cada cluster
        F_j_values = []
        n_cluster_points_l_values = []
        max_distance_l_values = []
        variancia_intra_l_values = []
        desvio_padrao_intra_l_values = []
        
        centroid_values.append(centroids.copy())
        # Loop sobre cada cluster
        for j in range(n_clusters):
            cluster_points = data[labels == j]  # Dados no cluster j
            centroid = centroids[j]             # Centróide do cluster j

            n_cluster_points_l_values.append(len(cluster_points))
            
            # Calcular dispersão intra-cluster F_j
            F_j = calcular_dispersaointra(cluster_points, centroid)
            F_j_values.append(float(F_j))
            
            # Calcular o diâmetro do cluster (maior distância entre os pontos dentro do cluster)
            max_distance = calcular_diametro(cluster_points)
            max_distance_l_values.append(float(max_distance))
            
            # Calcular a variância intra-classe
            variancia_intra = calcular_variancia_intra(cluster_points, centroid)
            variancia_intra_l_values.append(float(variancia_intra))
            
            # Calcular o desvio padrão intra-classe
            desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
            desvio_padrao_intra_l_values.append(float(desvio_padrao_intra))
        
        F_in_values.append(F_j_values.copy())
        
        # Calcular F_out (dispersão inter-cluster)
        F_out = calcular_dispersaointer(centroids, data, labels, n_clusters)
        
        F_out_values.append(F_out)
        n_cluster_points_values.append(n_cluster_points_l_values)
        max_distance_values.append(max_distance_l_values.copy())
        variancia_intra_values.append(variancia_intra_l_values.copy())
        desvio_padrao_intra_values.append(desvio_padrao_intra_l_values.copy())

    return F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values


def plot_metricas_clusters(F_out_values, F_in_values, max_clusters=10):
    # Número de clusters de 1 a max_clusters
    clusters_range = range(1, max_clusters + 1)

    # Calcular a dispersão total intra-cluster (F_in) para cada número de clusters
    total_F_in_values = [sum(F_in) for F_in in F_in_values]

    # Plotar as métricas
    plt.figure(figsize=(10, 6))

    # Gráfico da dispersão intra-cluster (F_in)
    plt.plot(clusters_range, total_F_in_values, label="Dispersão Intra-cluster (F_in)", marker='o', color='blue')

    # Gráfico da dissimilaridade inter-cluster (F_out)
    plt.plot(clusters_range, F_out_values, label="Dissimilaridade Inter-cluster (F_out)", marker='x', color='red')

    # Adicionando rótulos e título
    plt.xlabel("Número de clusters")
    plt.ylabel("Valor das métricas")
    plt.title("Dispersão intra-cluster (F_in) e Dissimilaridade inter-cluster (F_out) por número de clusters")
    plt.legend()
    plt.grid(True)

    # Exibir o gráfico
    plt.show()

# %%
for i, data_normalized in enumerate([data_all_normalized, data_train_normalized, data_val_normalized]):
    print()
    print()
    if i == 0:
        print("Total")
    elif i == 1:
        print("Treino")
    elif i == 2:
        print("Teste")
    print()
    print()
    F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values = calcular_metricas_cluster_kmeans(data_normalized, 10)
    for idx, (F_out, F_in, n_cluster_points, centroid, max_distance, variancia_intra, desvio_padrao_intra) in enumerate(zip(F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values)):
        print(f"Clusters: {idx+1}")
        print(f"   Número de elementos (n_j): ", n_cluster_points)
        print(f"   Baricentro (m_j): ", centroid)
        print(f"   Diâmetro do cluster: ", max_distance)
        print(f"   Variância intra-cluster: ", variancia_intra)
        print(f"   Desvio padrão intra-cluster: ", desvio_padrao_intra)
        print(f"   Dispersão intra-cluster (F_ji): ", F_in)
        print(f"   Dispersão total intra-cluster (F_in): {sum(F_in)}")
        print(f"   Dissimilaridade inter-cluster (F_out): {(F_out)}")
    
    plot_metricas_clusters(F_out_values, F_in_values, max_clusters=10)
# Out:
# Total
#
#
# Clusters: 1
#    Número de elementos (n_j):  [200]
#    Baricentro (m_j):  [[0.37344262 0.5125    ]]
#    Diâmetro do cluster:  [1.2835167594746568]
#    Variância intra-cluster:  [0.11811224935799813]
#    Desvio padrão intra-cluster:  [0.3436746271664496]
#    Dispersão intra-cluster (F_ji):  [23.622449871599628]
#    Dispersão total intra-cluster (F_in): 23.622449871599628
#    Dissimilaridade inter-cluster (F_out): 0.0
# Clusters: 2
#    Número de elementos (n_j):  [121, 79]
#    Baricentro (m_j):  [[0.36322991 0.68672521]
#  [0.38908487 0.24564873]]
#    Diâmetro do cluster:  [1.0002169903464837, 1.02364620963495]
#    Variância intra-cluster:  [0.06788030344761983, 0.07694354207340963]
#    Desvio padrão intra-cluster:  [0.2605384874593768, 0.27738698973349424]
#    Dispersão intra-cluster (F_ji):  [8.213516717162, 6.07853982379936]
#    Dispersão total intra-cluster (F_in): 14.29205654096136
#    Dissimilaridade inter-cluster (F_out): 9.760846668729227
# Clusters: 3
#    Número de elementos (n_j):  [110, 50, 40]
#    Baricentro (m_j):  [[0.25692996 0.55037879]
#  [0.46737705 0.16104167]
#  [0.57643443 0.84765625]]
#    Diâmetro do cluster:  [0.774597862628109, 0.9996493103170268, 0.8168729419368783]
#    Variância intra-cluster:  [0.03941721618332676, 0.07342231004256995, 0.030139823179317043]
#    Desvio padrão intra-cluster:  [0.1985376946157247, 0.2709655144895194, 0.17360824628835186]
#    Dispersão intra-cluster (F_ji):  [4.335893780165944, 3.6711155021284974, 1.2055929271726817]
#    Dispersão total intra-cluster (F_in): 9.212602209467123
#    Dissimilaridade inter-cluster (F_out): 15.143505606081833
# Clusters: 4
#    Número de elementos (n_j):  [100, 38, 39, 23]
#    Baricentro (m_j):  [[0.27262295 0.57791667]
#  [0.59016393 0.18366228]
#  [0.58638083 0.84508547]
#  [0.09265859 0.20742754]]
#    Diâmetro do cluster:  [0.7297326710279127, 0.5692291010729084, 0.5635721953728857, 0.39727154127378256]
#    Variância intra-cluster:  [0.03573889850025382, 0.02990911565651152, 0.02669104304869877, 0.02159124304726134]
#    Desvio padrão intra-cluster:  [0.18904734459984837, 0.17294252125059215, 0.16337393625881322, 0.14693958978866567]
#    Dispersão intra-cluster (F_ji):  [3.573889850025382, 1.1365463949474377, 1.040950678899252, 0.49659859008701085]
#    Dispersão total intra-cluster (F_in): 6.247985513959082
#    Dissimilaridade inter-cluster (F_out): 18.098988952884874
# Clusters: 5
#    Número de elementos (n_j):  [81, 35, 39, 23, 22]
#    Baricentro (m_j):  [[0.33029751 0.50540123]
#  [0.6        0.16785714]
#  [0.58638083 0.84508547]
#  [0.09265859 0.20742754]
#  [0.08792846 0.81628788]]
#    Diâmetro do cluster:  [0.3902145283571035, 0.5610065710808725, 0.5635721953728857, 0.39727154127378256, 0.40264887090202467]
#    Variância intra-cluster:  [0.009931691515412122, 0.02799216834677972, 0.02669104304869877, 0.02159124304726134, 0.01510012484980266]
#    Desvio padrão intra-cluster:  [0.09965787232031457, 0.16730860213025425, 0.16337393625881322, 0.14693958978866567, 0.12288256528003742]
#    Dispersão intra-cluster (F_ji):  [0.804467012748382, 0.9797258921372902, 1.040950678899252, 0.49659859008701085, 0.3322027466956585]
#    Dispersão total intra-cluster (F_in): 3.6539449205675933
#    Dissimilaridade inter-cluster (F_out): 20.202905356199736
# Clusters: 6
#    Número de elementos (n_j):  [78, 34, 39, 15, 22, 12]
#    Baricentro (m_j):  [[0.33869273 0.50707799]
#  [0.6027001  0.16207108]
#  [0.58638083 0.84508547]
#  [0.13551913 0.36319444]
#  [0.08792846 0.81628788]
#  [0.07855191 0.08940972]]
#    Diâmetro do cluster:  [0.4059972551758482, 0.5610065710808725, 0.5635721953728857, 0.23360880427449773, 0.40264887090202467, 0.1907465993646021]
#    Variância intra-cluster:  [0.009898463088288997, 0.027388550235955506, 0.02669104304869877, 0.009320126052999164, 0.01510012484980266, 0.005534983941075905]
#    Desvio padrão intra-cluster:  [0.09949102013895021, 0.1654948646815227, 0.16337393625881322, 0.09654079993971028, 0.12288256528003742, 0.07439747267935858]
#    Dispersão intra-cluster (F_ji):  [0.7720801208865418, 0.9312107080224872, 1.040950678899252, 0.13980189079498745, 0.3322027466956585, 0.06641980729291086]
#    Dispersão total intra-cluster (F_in): 3.2826659525918376
#    Dissimilaridade inter-cluster (F_out): 21.75097604574948
# Clusters: 7
#    Número de elementos (n_j):  [78, 24, 39, 15, 22, 12, 10]
#    Baricentro (m_j):  [[0.33869273 0.50707799]
#  [0.53039617 0.13845486]
#  [0.58638083 0.84508547]
#  [0.13551913 0.36319444]
#  [0.08792846 0.81628788]
#  [0.07855191 0.08940972]
#  [0.77622951 0.21875   ]]
#    Diâmetro do cluster:  [0.4059972551758482, 0.35426150513149995, 0.5635721953728857, 0.23360880427449773, 0.40264887090202467, 0.1907465993646021, 0.38061593954082507]
#    Variância intra-cluster:  [0.009898463088288997, 0.010953478551955984, 0.02669104304869877, 0.009320126052999164, 0.01510012484980266, 0.005534983941075905, 0.019622366672638773]
#    Desvio padrão intra-cluster:  [0.09949102013895021, 0.10465886752662663, 0.16337393625881322, 0.09654079993971028, 0.12288256528003742, 0.07439747267935858, 0.14007985819752522]
#    Dispersão intra-cluster (F_ji):  [0.7720801208865418, 0.2628834852469436, 1.040950678899252, 0.13980189079498745, 0.3322027466956585, 0.06641980729291086, 0.19622366672638775]
#    Dispersão total intra-cluster (F_in): 2.810562396542682
#    Dissimilaridade inter-cluster (F_out): 22.353263095512297
# Clusters: 8
#    Número de elementos (n_j):  [45, 29, 32, 20, 21, 7, 42, 4]
#    Baricentro (m_j):  [[0.39289617 0.475     ]
#  [0.56529112 0.15409483]
#  [0.53586066 0.85351562]
#  [0.08155738 0.83333333]
#  [0.08313817 0.19295635]
#  [0.81733021 0.80654762]
#  [0.25702576 0.53075397]
#  [0.89344262 0.171875  ]]
#    Diâmetro do cluster:  [0.28621115183472606, 0.43164008123847075, 0.3675715527280763, 0.34414067975325424, 0.39727154127378256, 0.3338973343325186, 0.3126074795014636, 0.2340026760132861]
#    Variância intra-cluster:  [0.0069308516726885455, 0.01601435699175309, 0.014076748348214324, 0.012720975077637428, 0.020192752751749667, 0.017541125434653842, 0.007693422138468795, 0.010713661050550178]
#    Desvio padrão intra-cluster:  [0.08325173675478816, 0.12654784467446725, 0.11864547335745398, 0.11278730016113263, 0.14210120601792817, 0.132442913871048, 0.08771215502123292, 0.10350681644486115]
#    Dispersão intra-cluster (F_ji):  [0.31188832527098453, 0.4644163527608396, 0.45045594714285836, 0.25441950155274856, 0.424047807786743, 0.12278787804257689, 0.3231237298156894, 0.04285464420220071]
#    Dispersão total intra-cluster (F_in): 2.3939941865746412
#    Dissimilaridade inter-cluster (F_out): 22.525436469689318
# Clusters: 9
#    Número de elementos (n_j):  [50, 18, 32, 20, 21, 7, 33, 4, 15]
#    Baricentro (m_j):  [[0.37360656 0.50041667]
#  [0.5273224  0.09606481]
#  [0.53586066 0.85351562]
#  [0.08155738 0.83333333]
#  [0.08313817 0.19295635]
#  [0.81733021 0.80654762]
#  [0.23745653 0.52209596]
#  [0.89344262 0.171875  ]
#  [0.59071038 0.27708333]]
#    Diâmetro do cluster:  [0.2552863482863278, 0.19791666666666666, 0.3675715527280763, 0.34414067975325424, 0.39727154127378256, 0.3338973343325186, 0.3126074795014636, 0.2340026760132861, 0.32242047085163045]
#    Variância intra-cluster:  [0.00553304527232823, 0.005739246618753385, 0.014076748348214324, 0.012720975077637428, 0.020192752751749667, 0.017541125434653842, 0.007384497052004057, 0.010713661050550178, 0.014941551081449629]
#    Desvio padrão intra-cluster:  [0.07438444240785992, 0.07575781556218068, 0.11864547335745398, 0.11278730016113263, 0.14210120601792817, 0.132442913871048, 0.0859330963715614, 0.10350681644486115, 0.12223563752625348]
#    Dispersão intra-cluster (F_ji):  [0.2766522636164115, 0.10330643913756093, 0.45045594714285836, 0.25441950155274856, 0.424047807786743, 0.12278787804257689, 0.24368840271613387, 0.04285464420220071, 0.22412326622174444]
#    Dispersão total intra-cluster (F_in): 2.1423361504189784
#    Dissimilaridade inter-cluster (F_out): 23.297720683140554
# Clusters: 10
#    Número de elementos (n_j):  [45, 18, 32, 20, 12, 7, 41, 4, 10, 11]
#    Baricentro (m_j):  [[0.39581056 0.47060185]
#  [0.5204918  0.10069444]
#  [0.53586066 0.85351562]
#  [0.08155738 0.83333333]
#  [0.07855191 0.08940972]
#  [0.81733021 0.80654762]
#  [0.26169532 0.53810976]
#  [0.89344262 0.171875  ]
#  [0.65737705 0.23645833]
#  [0.10804769 0.33617424]]
#    Diâmetro do cluster:  [0.31930576157738166, 0.21875, 0.3675715527280763, 0.34414067975325424, 0.1907465993646021, 0.3338973343325186, 0.26229780574419664, 0.2340026760132861, 0.2650198953419641, 0.22765898766880038]
#    Variância intra-cluster:  [0.007600610041154108, 0.005730802257623565, 0.014076748348214324, 0.012720975077637428, 0.005534983941075905, 0.017541125434653842, 0.006305027261053463, 0.010713661050550178, 0.008914209994793065, 0.006883129384688791]
#    Desvio padrão intra-cluster:  [0.08718147762658136, 0.07570206243969556, 0.11864547335745398, 0.11278730016113263, 0.07439747267935858, 0.132442913871048, 0.07940420178462512, 0.10350681644486115, 0.09441509410466668, 0.0829646273100096]
#    Dispersão intra-cluster (F_ji):  [0.34202745185193484, 0.10315444063722416, 0.45045594714285836, 0.25441950155274856, 0.06641980729291086, 0.12278787804257689, 0.258506117703192, 0.04285464420220071, 0.08914209994793065, 0.0757144232315767]
#    Dispersão total intra-cluster (F_in): 1.8054823116051537
#    Dissimilaridade inter-cluster (F_out): 23.522695455177356
# Treino
#
#
# Clusters: 1
#    Número de elementos (n_j):  [100]
#    Baricentro (m_j):  [[0.37901639 0.521875  ]]
#    Diâmetro do cluster:  [1.276693249687163]
#    Variância intra-cluster:  [0.12144108302119726]
#    Desvio padrão intra-cluster:  [0.3484839781413161]
#    Dispersão intra-cluster (F_ji):  [12.144108302119726]
#    Dispersão total intra-cluster (F_in): 12.144108302119726
#    Dissimilaridade inter-cluster (F_out): 0.0
# Clusters: 2
#    Número de elementos (n_j):  [36, 64]
#    Baricentro (m_j):  [[0.39913479 0.81655093]
#  [0.3676998  0.35611979]]
#    Diâmetro do cluster:  [1.0002169903464837, 1.02364620963495]
#    Variância intra-cluster:  [0.07612162725318711, 0.07025868109047205]
#    Desvio padrão intra-cluster:  [0.27590148106377954, 0.2650635416093131]
#    Dispersão intra-cluster (F_ji):  [2.7403785811147356, 4.496555589790211]
#    Dispersão total intra-cluster (F_in): 7.236934170904947
#    Dissimilaridade inter-cluster (F_out): 5.324624708349369
# Clusters: 3
#    Número de elementos (n_j):  [59, 20, 21]
#    Baricentro (m_j):  [[0.23450959 0.50794492]
#  [0.59221311 0.190625  ]
#  [0.58196721 0.8764881 ]]
#    Diâmetro do cluster:  [0.9479521049001909, 0.864843185636325, 0.5635721953728857]
#    Variância intra-cluster:  [0.048389310327925296, 0.04676455416097449, 0.02385862248427395]
#    Desvio padrão intra-cluster:  [0.21997570394915275, 0.2162511367853924, 0.15446236591569465]
#    Dispersão intra-cluster (F_ji):  [2.8549693093475925, 0.9352910832194898, 0.501031072169753]
#    Dispersão total intra-cluster (F_in): 4.291291464736835
#    Dissimilaridade inter-cluster (F_out): 8.673679835199763
# Clusters: 4
#    Número de elementos (n_j):  [10, 51, 21, 18]
#    Baricentro (m_j):  [[0.07213115 0.79270833]
#  [0.26984892 0.44076797]
#  [0.58196721 0.8764881 ]
#  [0.62204007 0.1875    ]]
#    Diâmetro do cluster:  [0.29270141886701945, 0.6815461363802239, 0.5635721953728857, 0.5490467421484504]
#    Variância intra-cluster:  [0.008759689807194153, 0.0336193974687876, 0.02385862248427395, 0.035609475235027416]
#    Desvio padrão intra-cluster:  [0.09359321453606641, 0.18335593109792658, 0.15446236591569465, 0.18870473029319487]
#    Dispersão intra-cluster (F_ji):  [0.08759689807194153, 1.7145892709081678, 0.501031072169753, 0.6409705542304935]
#    Dispersão total intra-cluster (F_in): 2.9441877953803557
#    Dissimilaridade inter-cluster (F_out): 9.48104777786409
# Clusters: 5
#    Número de elementos (n_j):  [10, 40, 21, 18, 11]
#    Baricentro (m_j):  [[0.07213115 0.79270833]
#  [0.3192623  0.49817708]
#  [0.58196721 0.8764881 ]
#  [0.62204007 0.1875    ]
#  [0.09016393 0.23200758]]
#    Diâmetro do cluster:  [0.29270141886701945, 0.3739378630376916, 0.5635721953728857, 0.5490467421484504, 0.39727154127378256]
#    Variância intra-cluster:  [0.008759689807194153, 0.009713185596360701, 0.02385862248427395, 0.035609475235027416, 0.023819888284675437]
#    Desvio padrão intra-cluster:  [0.09359321453606641, 0.09855549500845046, 0.15446236591569465, 0.18870473029319487, 0.1543369310459277]
#    Dispersão intra-cluster (F_ji):  [0.08759689807194153, 0.38852742385442807, 0.501031072169753, 0.6409705542304935, 0.2620187711314298]
#    Dispersão total intra-cluster (F_in): 1.8801447194580458
#    Dissimilaridade inter-cluster (F_out): 10.441577490049932
# Clusters: 6
#    Número de elementos (n_j):  [10, 40, 21, 9, 11, 9]
#    Baricentro (m_j):  [[0.07213115 0.79270833]
#  [0.3192623  0.49817708]
#  [0.58196721 0.8764881 ]
#  [0.71311475 0.26736111]
#  [0.09016393 0.23200758]
#  [0.53096539 0.10763889]]
#    Diâmetro do cluster:  [0.29270141886701945, 0.3739378630376916, 0.5635721953728857, 0.5263332736287747, 0.39727154127378256, 0.20849682568556321]
#    Variância intra-cluster:  [0.008759689807194153, 0.009713185596360701, 0.02385862248427395, 0.03522391577167959, 0.023819888284675437, 0.006650245437141882]
#    Desvio padrão intra-cluster:  [0.09359321453606641, 0.09855549500845046, 0.15446236591569465, 0.18768035531637187, 0.1543369310459277, 0.0815490370092859]
#    Dispersão intra-cluster (F_ji):  [0.08759689807194153, 0.38852742385442807, 0.501031072169753, 0.3170152419451163, 0.2620187711314298, 0.05985220893427694]
#    Dispersão total intra-cluster (F_in): 1.6160416161069455
#    Dissimilaridade inter-cluster (F_out): 10.88495029094046
# Clusters: 7
#    Número de elementos (n_j):  [10, 40, 6, 9, 11, 9, 15]
#    Baricentro (m_j):  [[0.07213115 0.79270833]
#  [0.3192623  0.49817708]
#  [0.74726776 0.91840278]
#  [0.71311475 0.26736111]
#  [0.09016393 0.23200758]
#  [0.53096539 0.10763889]
#  [0.51584699 0.85972222]]
#    Diâmetro do cluster:  [0.29270141886701945, 0.3739378630376916, 0.36795298805317017, 0.5263332736287747, 0.39727154127378256, 0.20849682568556321, 0.27507908515655466]
#    Variância intra-cluster:  [0.008759689807194153, 0.009713185596360701, 0.01744928738131467, 0.03522391577167959, 0.023819888284675437, 0.006650245437141882, 0.010136934215131998]
#    Desvio padrão intra-cluster:  [0.09359321453606641, 0.09855549500845046, 0.13209575080718786, 0.18768035531637187, 0.1543369310459277, 0.0815490370092859, 0.10068234311502687]
#    Dispersão intra-cluster (F_ji):  [0.08759689807194153, 0.38852742385442807, 0.10469572428788804, 0.3170152419451163, 0.2620187711314298, 0.05985220893427694, 0.15205401322697995]
#    Dispersão total intra-cluster (F_in): 1.3717602814520606
#    Dissimilaridade inter-cluster (F_out): 11.003320746774657
# Clusters: 8
#    Número de elementos (n_j):  [10, 38, 6, 15, 8, 15, 5, 3]
#    Baricentro (m_j):  [[0.07213115 0.79270833]
#  [0.32528041 0.50191886]
#  [0.74726776 0.91840278]
#  [0.56557377 0.18958333]
#  [0.125      0.36979167]
#  [0.51584699 0.85972222]
#  [0.08032787 0.08958333]
#  [0.90437158 0.17708333]]
#    Diâmetro do cluster:  [0.29270141886701945, 0.3739378630376916, 0.36795298805317017, 0.43164008123847075, 0.22765898766880038, 0.27507908515655466, 0.1621660980857122, 0.2340026760132861]
#    Variância intra-cluster:  [0.008759689807194153, 0.009220032948586388, 0.01744928738131467, 0.02083494766938398, 0.00903565262334274, 0.010136934215131998, 0.005737707250888351, 0.013698605636676716]
#    Desvio padrão intra-cluster:  [0.09359321453606641, 0.09602100264310089, 0.13209575080718786, 0.1443431594131983, 0.09505604990395267, 0.10068234311502687, 0.07574765508508069, 0.11704104253071533]
#    Dispersão intra-cluster (F_ji):  [0.08759689807194153, 0.35036125204628277, 0.10469572428788804, 0.31252421504075967, 0.07228522098674192, 0.15205401322697995, 0.028688536254441753, 0.04109581691003015]
#    Dispersão total intra-cluster (F_in): 1.1493016768250657
#    Dissimilaridade inter-cluster (F_out): 11.258094632239757
# Clusters: 9
#    Número de elementos (n_j):  [10, 19, 6, 13, 8, 15, 5, 3, 21]
#    Baricentro (m_j):  [[0.07213115 0.79270833]
#  [0.40293356 0.45175439]
#  [0.74726776 0.91840278]
#  [0.57313997 0.16346154]
#  [0.125      0.36979167]
#  [0.51584699 0.85972222]
#  [0.08032787 0.08958333]
#  [0.90437158 0.17708333]
#  [0.27322404 0.53373016]]
#    Diâmetro do cluster:  [0.29270141886701945, 0.250638387347865, 0.36795298805317017, 0.43164008123847075, 0.22765898766880038, 0.27507908515655466, 0.1621660980857122, 0.2340026760132861, 0.2194154513357472]
#    Variância intra-cluster:  [0.008759689807194153, 0.005508546318781319, 0.01744928738131467, 0.018478847435398287, 0.00903565262334274, 0.010136934215131998, 0.005737707250888351, 0.013698605636676716, 0.0056681825424586925]
#    Desvio padrão intra-cluster:  [0.09359321453606641, 0.07421958177449749, 0.13209575080718786, 0.13593692447380987, 0.09505604990395267, 0.10068234311502687, 0.07574765508508069, 0.11704104253071533, 0.07528733321388593]
#    Dispersão intra-cluster (F_ji):  [0.08759689807194153, 0.10466238005684506, 0.10469572428788804, 0.24022501666017773, 0.07228522098674192, 0.15205401322697995, 0.028688536254441753, 0.04109581691003015, 0.11903183339163255]
#    Dispersão total intra-cluster (F_in): 0.9503354398466787
#    Dissimilaridade inter-cluster (F_out): 11.435966367843479
# Clusters: 10
#    Número de elementos (n_j):  [10, 17, 6, 13, 6, 15, 5, 3, 12, 13]
#    Baricentro (m_j):  [[0.07213115 0.79270833]
#  [0.40887175 0.44546569]
#  [0.74726776 0.91840278]
#  [0.57313997 0.16346154]
#  [0.09836066 0.35069444]
#  [0.51584699 0.85972222]
#  [0.08032787 0.08958333]
#  [0.90437158 0.17708333]
#  [0.29713115 0.57638889]
#  [0.25283733 0.47355769]]
#    Diâmetro do cluster:  [0.29270141886701945, 0.22035921684942344, 0.36795298805317017, 0.43164008123847075, 0.22765898766880038, 0.27507908515655466, 0.1621660980857122, 0.2340026760132861, 0.19861462961342863, 0.12891572069222498]
#    Variância intra-cluster:  [0.008759689807194153, 0.004933292689338884, 0.01744928738131467, 0.018478847435398287, 0.007750102593803603, 0.010136934215131998, 0.005737707250888351, 0.013698605636676716, 0.004761034199455211, 0.0027467417572289484]
#    Desvio padrão intra-cluster:  [0.09359321453606641, 0.07023740235329667, 0.13209575080718786, 0.13593692447380987, 0.08803466700001542, 0.10068234311502687, 0.07574765508508069, 0.11704104253071533, 0.06900024782169417, 0.052409367075256195]
#    Dispersão intra-cluster (F_ji):  [0.08759689807194153, 0.08386597571876103, 0.10469572428788804, 0.24022501666017773, 0.04650061556282162, 0.15205401322697995, 0.028688536254441753, 0.04109581691003015, 0.05713241039346253, 0.03570764284397633]
#    Dispersão total intra-cluster (F_in): 0.8775626499304806
#    Dissimilaridade inter-cluster (F_out): 11.430332116814274
# Teste
#
#
# Clusters: 1
#    Número de elementos (n_j):  [100]
#    Baricentro (m_j):  [[0.36786885 0.503125  ]]
#    Diâmetro do cluster:  [1.1970259717940903]
#    Variância intra-cluster:  [0.11454550060980845]
#    Desvio padrão intra-cluster:  [0.33844571294346226]
#    Dispersão intra-cluster (F_ji):  [11.454550060980845]
#    Dispersão total intra-cluster (F_in): 11.454550060980845
#    Dissimilaridade inter-cluster (F_out): 0.0
# Clusters: 2
#    Número de elementos (n_j):  [62, 38]
#    Baricentro (m_j):  [[0.36277102 0.6765793 ]
#  [0.37618637 0.22012061]]
#    Diâmetro do cluster:  [0.9148945868194676, 0.8587997840445235]
#    Variância intra-cluster:  [0.06311083074538572, 0.06917383233060222]
#    Desvio padrão intra-cluster:  [0.25121869107489936, 0.26300918677985796]
#    Dispersão intra-cluster (F_ji):  [3.9128715062139143, 2.6286056285628843]
#    Dispersão total intra-cluster (F_in): 6.541477134776798
#    Dissimilaridade inter-cluster (F_out): 5.213362612695293
# Clusters: 3
#    Número de elementos (n_j):  [50, 31, 19]
#    Baricentro (m_j):  [[0.4042623  0.570625  ]
#  [0.38286621 0.17473118]
#  [0.24762726 0.86129386]]
#    Diâmetro do cluster:  [0.7622401666386577, 0.8587997840445235, 0.5974866986318222]
#    Variância intra-cluster:  [0.037191826105680226, 0.07255990089254695, 0.05207151170084872]
#    Desvio padrão intra-cluster:  [0.19285182422181085, 0.2693694505554536, 0.22819183092487935]
#    Dispersão intra-cluster (F_ji):  [1.8595913052840114, 2.2493569276689556, 0.9893587223161256]
#    Dispersão total intra-cluster (F_in): 5.098306955269092
#    Dissimilaridade inter-cluster (F_out): 6.514052717226221
# Clusters: 4
#    Número de elementos (n_j):  [52, 19, 17, 12]
#    Baricentro (m_j):  [[0.40747163 0.58032853]
#  [0.56471096 0.1683114 ]
#  [0.21938284 0.86580882]
#  [0.09494536 0.18489583]]
#    Diâmetro do cluster:  [0.7622401666386577, 0.447755703262271, 0.5974866986318222, 0.3649626982261056]
#    Variância intra-cluster:  [0.03846271458438892, 0.021187355474104906, 0.05015036008860679, 0.018475876470359975]
#    Desvio padrão intra-cluster:  [0.1961191336519436, 0.1455587698289076, 0.22394276074168323, 0.13592599630078117]
#    Dispersão intra-cluster (F_ji):  [2.000061158388224, 0.4025597540079932, 0.8525561215063153, 0.2217105176443197]
#    Dispersão total intra-cluster (F_in): 3.4768875515468523
#    Dissimilaridade inter-cluster (F_out): 8.475457176591497
# Clusters: 5
#    Número de elementos (n_j):  [41, 18, 11, 12, 18]
#    Baricentro (m_j):  [[0.33446621 0.5203252 ]
#  [0.57058288 0.15798611]
#  [0.0923994  0.85132576]
#  [0.09494536 0.18489583]
#  [0.59153005 0.80844907]]
#    Diâmetro do cluster:  [0.4079889214478587, 0.4358363770435195, 0.40264887090202467, 0.3649626982261056, 0.5010887538953908]
#    Variância intra-cluster:  [0.009709973939474814, 0.01968369968108309, 0.01714580830429949, 0.018475876470359975, 0.027453587986147516]
#    Desvio padrão intra-cluster:  [0.0985392000143842, 0.1402986089777197, 0.130942003590519, 0.13592599630078117, 0.16569124293742116]
#    Dispersão intra-cluster (F_ji):  [0.3981089315184674, 0.3543065942594957, 0.1886038913472944, 0.2217105176443197, 0.4941645837506553]
#    Dispersão total intra-cluster (F_in): 1.6568945185202324
#    Dissimilaridade inter-cluster (F_out): 9.894493992657422
# Clusters: 6
#    Número de elementos (n_j):  [9, 18, 10, 11, 15, 37]
#    Baricentro (m_j):  [[0.44808743 0.62384259]
#  [0.57058288 0.15798611]
#  [0.09098361 0.87395833]
#  [0.085693   0.16856061]
#  [0.60655738 0.82777778]
#  [0.31169694 0.50929054]]
#    Diâmetro do cluster:  [0.21791818852175973, 0.4358363770435195, 0.2854474198791466, 0.33123595679214646, 0.5010887538953908, 0.44449752831874945]
#    Variância intra-cluster:  [0.008293637059837964, 0.01968369968108309, 0.013203771492598307, 0.015926151891585714, 0.02836249195424036, 0.011279530553554858]
#    Desvio padrão intra-cluster:  [0.09106940792515324, 0.1402986089777197, 0.11490766507330269, 0.12619885851934523, 0.1684116740438155, 0.10620513430882171]
#    Dispersão intra-cluster (F_ji):  [0.07464273353854167, 0.3543065942594957, 0.13203771492598307, 0.17518767080744285, 0.4254373793136054, 0.41734263048152975]
#    Dispersão total intra-cluster (F_in): 1.5789547233265984
#    Dissimilaridade inter-cluster (F_out): 9.956475229898768
# Clusters: 7
#    Número de elementos (n_j):  [24, 17, 10, 11, 11, 20, 7]
#    Baricentro (m_j):  [[0.38831967 0.48784722]
#  [0.57666345 0.14705882]
#  [0.09098361 0.87395833]
#  [0.085693   0.16856061]
#  [0.50372578 0.84943182]
#  [0.25819672 0.54791667]
#  [0.7295082  0.74404762]]
#    Diâmetro do cluster:  [0.2666626446475388, 0.43162863002365703, 0.2854474198791466, 0.33123595679214646, 0.24084196015942289, 0.3020833333333333, 0.3395874139454942]
#    Variância intra-cluster:  [0.007019138753531426, 0.018026742408045263, 0.013203771492598307, 0.015926151891585714, 0.009553122583855708, 0.007904587723767505, 0.01764295696050973]
#    Desvio padrão intra-cluster:  [0.08378030050991359, 0.13426370473082166, 0.11490766507330269, 0.12619885851934523, 0.09774007665157475, 0.08890774838993228, 0.1328267930822307]
#    Dispersão intra-cluster (F_ji):  [0.16845933008475422, 0.30645462093676945, 0.13203771492598307, 0.17518767080744285, 0.10508434842241278, 0.15809175447535012, 0.1235006987235681]
#    Dispersão total intra-cluster (F_in): 1.1688161383762805
#    Dissimilaridade inter-cluster (F_out): 10.472554251575929
# Clusters: 8
#    Número de elementos (n_j):  [24, 17, 7, 10, 7, 19, 5, 11]
#    Baricentro (m_j):  [[0.38831967 0.48784722]
#  [0.57666345 0.14705882]
#  [0.07728337 0.08928571]
#  [0.09098361 0.87395833]
#  [0.7295082  0.74404762]
#  [0.26143227 0.55756579]
#  [0.11967213 0.31875   ]
#  [0.50372578 0.84943182]]
#    Diâmetro do cluster:  [0.2666626446475388, 0.43162863002365703, 0.18680921315975882, 0.2854474198791466, 0.3395874139454942, 0.25214079369298403, 0.1612102354258152, 0.24084196015942289]
#    Variância intra-cluster:  [0.007019138753531426, 0.018026742408045263, 0.005386282603608495, 0.013203771492598307, 0.01764295696050973, 0.006249131835233202, 0.0050384197982919765, 0.009553122583855708]
#    Desvio padrão intra-cluster:  [0.08378030050991359, 0.13426370473082166, 0.07339129787385215, 0.11490766507330269, 0.1328267930822307, 0.07905145055742621, 0.07098182723973775, 0.09774007665157475]
#    Dispersão intra-cluster (F_ji):  [0.16845933008475422, 0.30645462093676945, 0.03770397822525946, 0.13203771492598307, 0.1235006987235681, 0.11873350486943084, 0.025192098991459883, 0.10508434842241278]
#    Dispersão total intra-cluster (F_in): 1.0171662951796379
#    Dissimilaridade inter-cluster (F_out): 10.499900552026338
# Clusters: 9
#    Número de elementos (n_j):  [16, 16, 7, 10, 7, 14, 5, 11, 14]
#    Baricentro (m_j):  [[0.37090164 0.55533854]
#  [0.58452869 0.13802083]
#  [0.07728337 0.08928571]
#  [0.09098361 0.87395833]
#  [0.7295082  0.74404762]
#  [0.23887588 0.55654762]
#  [0.11967213 0.31875   ]
#  [0.50372578 0.84943182]
#  [0.38992974 0.42261905]]
#    Diâmetro do cluster:  [0.16114465086528118, 0.40500226724125576, 0.18680921315975882, 0.2854474198791466, 0.3395874139454942, 0.25214079369298403, 0.1612102354258152, 0.24084196015942289, 0.22035921684942342]
#    Variância intra-cluster:  [0.0028910840941285647, 0.016713111269395363, 0.005386282603608495, 0.013203771492598307, 0.01764295696050973, 0.0063013541255322325, 0.0050384197982919765, 0.009553122583855708, 0.005520563436227309]
#    Desvio padrão intra-cluster:  [0.0537688022381805, 0.12927919890452355, 0.07339129787385215, 0.11490766507330269, 0.1328267930822307, 0.07938106906266905, 0.07098182723973775, 0.09774007665157475, 0.07430049418561971]
#    Dispersão intra-cluster (F_ji):  [0.046257345506057035, 0.2674097803103258, 0.03770397822525946, 0.13203771492598307, 0.1235006987235681, 0.08821895775745126, 0.025192098991459883, 0.10508434842241278, 0.07728788810718232]
#    Dispersão total intra-cluster (F_in): 0.9026928109696997
#    Dissimilaridade inter-cluster (F_out): 10.604435676614026
# Clusters: 10
#    Número de elementos (n_j):  [16, 16, 7, 10, 7, 14, 5, 6, 14, 5]
#    Baricentro (m_j):  [[0.37090164 0.55533854]
#  [0.58452869 0.13802083]
#  [0.07728337 0.08928571]
#  [0.09098361 0.87395833]
#  [0.52693208 0.73660714]
#  [0.23887588 0.55654762]
#  [0.11967213 0.31875   ]
#  [0.5068306  0.92361111]
#  [0.38992974 0.42261905]
#  [0.78360656 0.77083333]]
#    Diâmetro do cluster:  [0.16114465086528118, 0.40500226724125576, 0.18680921315975882, 0.2854474198791466, 0.20170320906141198, 0.25214079369298403, 0.1612102354258152, 0.14115565655159448, 0.22035921684942342, 0.22061473517029007]
#    Variância intra-cluster:  [0.0028910840941285647, 0.016713111269395363, 0.005386282603608495, 0.013203771492598307, 0.00504854581972088, 0.0063013541255322325, 0.0050384197982919765, 0.003597357242718174, 0.005520563436227309, 0.01154842121666816]
#    Desvio padrão intra-cluster:  [0.0537688022381805, 0.12927919890452355, 0.07339129787385215, 0.11490766507330269, 0.07105311970435134, 0.07938106906266905, 0.07098182723973775, 0.05997797297940448, 0.07430049418561971, 0.1074635808851918]
#    Dispersão intra-cluster (F_ji):  [0.046257345506057035, 0.2674097803103258, 0.03770397822525946, 0.13203771492598307, 0.03533982073804616, 0.08821895775745126, 0.025192098991459883, 0.021584143456309043, 0.07728788810718232, 0.0577421060833408]
#    Dispersão total intra-cluster (F_in): 0.7887738341014149
#    Dissimilaridade inter-cluster (F_out): 10.791437925267628

# %%
## Testando o valor da heurística maior queda (3) e observaçõa (5)
for i, (data, data_normalized) in enumerate([(data_all, data_all_normalized), (data_train, data_train_normalized), (data_val, data_val_normalized)]):
    print()
    print()
    if i == 0:
        print("Total")
    elif i == 1:
        print("Treino")
    elif i == 2:
        print("Teste")
    print()
    print()
    for optimal_clusters in [3, 4, 5]:
        print(f"Clusters: {optimal_clusters}")
        kmeans = KMeans(n_clusters=optimal_clusters, random_state=0)
        kmeans.fit(data_normalized)
        
        # Obtendo os centróides e rótulos
        m_0 = scaler.inverse_transform(kmeans.cluster_centers_)
        labels = kmeans.labels_
    
        # Plotando os clusters e seus centróides
        plt.figure(figsize=(8, 5))
        for i in range(optimal_clusters):
            cluster_points = data[labels == i]
            plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f"Cluster {i+1}")
        
        plt.scatter(m_0[:, 0], m_0[:, 1], marker='x', s=200, linewidths=2, color='k', label='Centróide')
        plt.title("Clusters de Clientes")
        plt.xlabel("Renda Anual (k$)")
        plt.ylabel("Pontuação de Gastos (1-100)")
        plt.legend()
        plt.grid()
        plt.show()
# Out:
# Total
#
#
# Clusters: 3
# Clusters: 4
# Clusters: 5
# Treino
#
#
# Clusters: 3
# Clusters: 4
# Clusters: 5
# Teste
#
#
# Clusters: 3
# Clusters: 4
# Clusters: 5

# %%
## Testando o valor da heurística maior queda (3) e observaçõa (5)
data, data_normalized = ((data_train, data_val), (data_train_normalized, data_val_normalized))
for optimal_clusters in [3, 4, 5]:
    print(f"Clusters: {optimal_clusters}")
    kmeans = KMeans(n_clusters=optimal_clusters, random_state=0)
    kmeans.fit(data_normalized[0])
    
    # Obtendo os centróides e rótulos
    m_0 = scaler.inverse_transform(kmeans.cluster_centers_)
    labels = kmeans.labels_

    kmeans_val = KMeans(n_clusters=optimal_clusters, random_state=0)
    kmeans_val.fit(data_normalized[1])
    
    # Obtendo os centróides e rótulos
    m_0_val = scaler.inverse_transform(kmeans_val.cluster_centers_)
    labels_val = kmeans_val.labels_

    # Plotando os clusters e seus centróides
    plt.figure(figsize=(8, 5))
    for i in range(optimal_clusters):
        cluster_points = data[0][labels == i]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f"Cluster {i+1}")
    
    plt.scatter(m_0[:, 0], m_0[:, 1], marker='x', s=200, linewidths=2, color='k', label='Centróide treino')
    plt.scatter(m_0_val[:, 0], m_0_val[:, 1], marker='p', s=200, linewidths=2, color='k', label='Centróide validação')
    plt.title("Clusters de Clientes")
    plt.xlabel("Renda Anual (k$)")
    plt.ylabel("Pontuação de Gastos (1-100)")
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# Clusters: 3
# Clusters: 4
# Clusters: 5

# %% [markdown]
# ## SOM

# %%
data_normalized, data, n_0 = data_all_normalized, data_all, n_0_all

# Eu uso topografia linear som
som_shape = (1, int(5*np.sqrt(n_0)))

som = MiniSom(som_shape[0], som_shape[1], data_normalized.shape[1], sigma=0.5, learning_rate=0.5)

max_iter = 1000
q_error = []
t_error = []

for i in range(max_iter):
    rand_i = np.random.randint(len(data_normalized))
    som.update(data_normalized[rand_i], som.winner(data_normalized[rand_i]), i, max_iter)
    q_error.append(som.quantization_error(data_normalized))
    t_error.append(som.topographic_error(data_normalized))

plt.plot(np.arange(max_iter), q_error, label='erro de quantização')
plt.plot(np.arange(max_iter), t_error, label='erro topográfico')
plt.ylabel('Erro de quantização')
plt.xlabel('Índice de iteração')
plt.legend()
plt.show()

# %%
# cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Plotando os clusters 
plt.figure(figsize=(8,5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster='+str(c), alpha=.7)

# Plotando centróides
for centroid in som.get_weights():
    centroid = scaler.inverse_transform(centroid)
    plt.scatter(centroid[:,0], centroid[:, 1], marker='x', 
                s=10, linewidths=20, color='k', label='Centróide') # label='centróide'
    
plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();
plt.plot()

# Supondo que 'som', 'data_normalized', 'som_shape' e 'scaler' já estejam definidos no seu código

# Cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# Com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = data[cluster_index == c]
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(F_j)
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data, cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 5  6 10 13 23 24 25 26 28 30 31 32 33 34 38 39 42 44 57 58]
# F_out (Dispersão inter-cluster): 9560.785737819819
# F_in (Dispersão intra-cluster) por cluster: 11099.170874155086
# Número de pontos por cluster: [4, 1, 1, 4, 9, 22, 11, 2, 3, 14, 12, 19, 19, 28, 1, 2, 14, 5, 15, 14]
# Centróides dos clusters: [array([101.,  77.]), array([126.,  28.]), array([38., 92.]), array([124.  ,  81.75]), array([25.88888889, 32.77777778]), array([46.81818182, 44.77272727]), array([76.18181818,  6.90909091]), array([98. , 35.5]), array([71.        , 91.33333333]), array([83.78571429, 90.57142857]), array([24.58333333,  9.58333333]), array([44.89473684, 56.94736842]), array([66.42105263, 40.        ]), array([60.85714286, 52.89285714]), array([137.,  18.]), array([116.5,  12. ]), array([77.78571429, 73.28571429]), array([24.4, 94. ]), array([88.73333333, 18.8       ]), array([24.21428571, 75.57142857])]
# Máxima distância (diâmetro) por cluster: [18.439088914585774, 0.0, 0.0, 25.298221281347036, 26.40075756488817, 20.615528128088304, 16.0312195418814, 7.280109889280518, 7.280109889280518, 25.079872407968907, 21.095023109728988, 26.68332812825267, 20.8806130178211, 16.55294535724685, 0.0, 10.63014581273465, 22.02271554554524, 15.652475842498529, 25.96150997149434, 22.80350850198276]
# Variância intra-cluster por cluster: [78.5, 0.0, 0.0, 116.1875, 81.16049382716051, 47.142561983471076, 34.049586776859506, 13.25, 10.888888888888888, 77.84183673469387, 66.65277777777777, 46.880886426592795, 53.19113573407202, 32.21811224489796, 0.0, 28.250000000000004, 52.65816326530612, 52.239999999999995, 97.42222222222222, 64.98469387755104]
# Desvio padrão intra-cluster por cluster: [8.860022573334675, 0.0, 0.0, 10.779030568655049, 9.008911911388662, 6.8660441291526135, 5.8352023766840775, 3.640054944640259, 3.2998316455372216, 8.822802090871917, 8.164115247703071, 6.846961839136596, 7.293225331365542, 5.676100091162766, 0.0, 5.315072906367325, 7.256594467469305, 7.227724399837061, 9.870269612438266, 8.0613084469924]

# %%
# removendo neuronios não treinados
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Plotando os clusters 
plt.figure(figsize=(8,5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster='+str(c), alpha=.7)

i=False
for centroid in som.get_weights()[0]:
    # Filtrando centróides próximos de 0
    if centroid[1] > min(data_normalized[:,1]) and centroid[0] > min(data_normalized[:,0]):  # Verifica se qualquer coordenada é maior que a tolerância
        centroid = scaler.inverse_transform([centroid])[0]
        plt.scatter(centroid[0], centroid[1], marker='x', 
                    s=10, linewidths=20, color='k', label='Centróide' if not i else None) # label='centróide'
        i = True
    
plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();
plt.plot()

# Supondo que 'som', 'data_normalized', 'som_shape' e 'scaler' já estejam definidos no seu código

# Cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# Com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = data_normalized[cluster_index == c]
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(float(F_j))
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data_normalized, cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {F_j_values}")
print(f"F_in (Dispersão intra-cluster): {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 5  6 10 13 23 24 25 26 28 30 31 32 33 34 38 39 42 44 57 58]
# F_out (Dispersão inter-cluster): 0.805673056438345
# F_in (Dispersão intra-cluster) por cluster: [0.03307948365508077, 0.0, 0.0, 0.03761918413275628, 0.056825743569198506, 0.08554280867369275, 0.03123468798438566, 0.0027927926194048804, 0.0032139945516935853, 0.0824508307365318, 0.06641980729291086, 0.06971873300698894, 0.08194957549886765, 0.07898361894650643, 0.0, 0.005118285108543109, 0.057251724846751395, 0.021433192148914548, 0.11100743900982413, 0.07134900439056746]
# F_in (Dispersão intra-cluster): 0.8959909061726188
# Número de pontos por cluster: [4, 1, 1, 4, 9, 22, 11, 2, 3, 14, 12, 19, 19, 28, 1, 2, 14, 5, 15, 14]
# Centróides dos clusters: [array([0.70491803, 0.79166667]), array([0.90983607, 0.28125   ]), array([0.18852459, 0.94791667]), array([0.89344262, 0.84114583]), array([0.08925319, 0.33101852]), array([0.26080477, 0.45596591]), array([0.50149031, 0.06155303]), array([0.68032787, 0.359375  ]), array([0.45901639, 0.94097222]), array([0.56381733, 0.93303571]), array([0.07855191, 0.08940972]), array([0.24503883, 0.58278509]), array([0.42148404, 0.40625   ]), array([0.37587822, 0.5405506 ]), array([1.        , 0.17708333]), array([0.83196721, 0.11458333]), array([0.514637  , 0.75297619]), array([0.07704918, 0.96875   ]), array([0.60437158, 0.18541667]), array([0.07552693, 0.77678571])]
# Máxima distância (diâmetro) por cluster: [0.19034502841978282, 0.0, 0.0, 0.21364390661343388, 0.22765898766880038, 0.1885135303291461, 0.1315605733131747, 0.07473677300238325, 0.0747367730023832, 0.21941252747805706, 0.1907465993646021, 0.2220904059485793, 0.18614680420863047, 0.15412506308585064, 0.0, 0.10117593694691547, 0.20170320906141198, 0.14947783790849897, 0.21750457567376544, 0.1908517494938667]
# Variância intra-cluster por cluster: [0.008269870913770192, 0.0, 0.0, 0.00940479603318907, 0.0063139715076887225, 0.0038883094851678525, 0.0028395170894896056, 0.0013963963097024402, 0.0010713315172311952, 0.005889345052609414, 0.005534983941075905, 0.003669407000367839, 0.004313135552571981, 0.002820843533803801, 0.0, 0.0025591425542715544, 0.004089408917625099, 0.0042866384297829095, 0.007400495933988275, 0.005096357456469104]
# Desvio padrão intra-cluster por cluster: [0.09093883061580565, 0.0, 0.0, 0.09697832764689784, 0.07946050281547885, 0.062356310708442754, 0.053287119358148886, 0.03736838650119162, 0.032731200974470756, 0.07674206833679566, 0.07439747267935858, 0.06057563041659442, 0.06567446651912737, 0.05311161392580535, 0.0, 0.05058796847345774, 0.06394848643732781, 0.06547242495725135, 0.08602613517988748, 0.07138877682429573]

# %%
import numpy as np

# Função para calcular a distância entre dois pontos (centróides)
def calcular_distancia(centroid1, centroid2):
    return np.linalg.norm(centroid1 - centroid2)

# Função para decidir se clusters devem ser agrupados ou bipartidos
def verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points ,threshold=2, population_threshold = 5):
    n_clusters = len(centroid_values)
    agrupamentos = []  # Lista para armazenar decisões de agrupamento
    
    for i in range(n_clusters):
        for j in range(n_clusters):
            if i == j or (i,j) in agrupamentos:
                continue
            # Calcular a distância entre os centróides dos clusters i e j
            dist = calcular_distancia(centroid_values[i], centroid_values[j])

            sigma_sum = sigma_values[i] + sigma_values[j]
            
            # Comparar a distância entre centróides com a soma das dispersões
            if dist < sigma_sum * threshold:  # Se a distância for muito pequena, agrupar
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[j]))  # Armazenar os pares de clusters que devem ser agrupados
                print(f"Clusters {np.unique(cluster_index)[i]} e {np.unique(cluster_index)[j]} podem ser agrupados. Distância: {dist}, Soma das dispersões: {sigma_sum}")
            elif F_values[i] > F_values[j] and F_values[i] > 10 * F_values[j]:  # Se F_k for muito maior em um cluster
                print(f"Cluster {np.unique(cluster_index)[i]} tem alta dispersão (F_k), considerar bipartição.")
    for i in range(n_clusters):
        if n_cluster_points[i] < population_threshold:
            # Encontrar o cluster mais próximo para agrupar
            min_dist = float('inf')
            closest_cluster = None
            for j in range(n_clusters):
                if i != j and n_cluster_points[j] >= population_threshold:  # Não agrupar com clusters de baixa população
                    dist = calcular_distancia(centroid_values[i], centroid_values[j])
                    if dist < min_dist:
                        min_dist = dist
                        closest_cluster = j
            
            if closest_cluster is not None:
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[closest_cluster]))
                print(f"Cluster {np.unique(cluster_index)[i]} tem população baixa e será agrupado com o cluster {np.unique(cluster_index)[closest_cluster]}. Distância: {min_dist}")

        
    
    return agrupamentos

# Exemplo de centróides, dispersões e sigma (desvio padrão)
centroid_values = centroid_values

# Exemplo de dispersão F (somatória da distância intra-cluster)
F_values = F_j_values

# Exemplo de desvio padrão intra-cluster (σ)
sigma_values = desvio_padrao_intra_values

# Chamando a função para verificar agrupamento e bipartição
agrupamentos = verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points_values, 1.4, 7)

# Se necessário, implementar a lógica de bipartição para clusters com alta dispersão F_k
# Out:
# Cluster 5 tem alta dispersão (F_k), considerar bipartição.
# Cluster 5 tem alta dispersão (F_k), considerar bipartição.
# Clusters 5 e 13 podem ser agrupados. Distância: 0.19490948932904015, Soma das dispersões: 0.1879171582627035
# Cluster 5 tem alta dispersão (F_k), considerar bipartição.
# Cluster 5 tem alta dispersão (F_k), considerar bipartição.
# Clusters 5 e 30 podem ser agrupados. Distância: 0.19973636597322264, Soma das dispersões: 0.1676808989526013
# Cluster 5 tem alta dispersão (F_k), considerar bipartição.
# Clusters 5 e 42 podem ser agrupados. Distância: 0.1941747241405109, Soma das dispersões: 0.15488731705313347
# Clusters 13 e 5 podem ser agrupados. Distância: 0.19490948932904015, Soma das dispersões: 0.1879171582627035
# Cluster 13 tem alta dispersão (F_k), considerar bipartição.
# Cluster 13 tem alta dispersão (F_k), considerar bipartição.
# Cluster 13 tem alta dispersão (F_k), considerar bipartição.
# Cluster 13 tem alta dispersão (F_k), considerar bipartição.
# Cluster 13 tem alta dispersão (F_k), considerar bipartição.
# Cluster 23 tem alta dispersão (F_k), considerar bipartição.
# Cluster 23 tem alta dispersão (F_k), considerar bipartição.
# Cluster 23 tem alta dispersão (F_k), considerar bipartição.
# Cluster 23 tem alta dispersão (F_k), considerar bipartição.
# Cluster 23 tem alta dispersão (F_k), considerar bipartição.
# Cluster 23 tem alta dispersão (F_k), considerar bipartição.
# Cluster 24 tem alta dispersão (F_k), considerar bipartição.
# Cluster 24 tem alta dispersão (F_k), considerar bipartição.
# Cluster 24 tem alta dispersão (F_k), considerar bipartição.
# Cluster 24 tem alta dispersão (F_k), considerar bipartição.
# Clusters 24 e 32 podem ser agrupados. Distância: 0.12779541857432233, Soma das dispersões: 0.12293194112503716
# Clusters 24 e 33 podem ser agrupados. Distância: 0.16819482480440792, Soma das dispersões: 0.12803077722757011
# Cluster 24 tem alta dispersão (F_k), considerar bipartição.
# Cluster 24 tem alta dispersão (F_k), considerar bipartição.
# Cluster 25 tem alta dispersão (F_k), considerar bipartição.
# Cluster 25 tem alta dispersão (F_k), considerar bipartição.
# Cluster 25 tem alta dispersão (F_k), considerar bipartição.
# Cluster 25 tem alta dispersão (F_k), considerar bipartição.
# Clusters 25 e 57 podem ser agrupados. Distância: 0.16101787629568612, Soma das dispersões: 0.13931325453803636
# Cluster 26 tem alta dispersão (F_k), considerar bipartição.
# Cluster 26 tem alta dispersão (F_k), considerar bipartição.
# Cluster 26 tem alta dispersão (F_k), considerar bipartição.
# Cluster 28 tem alta dispersão (F_k), considerar bipartição.
# Cluster 28 tem alta dispersão (F_k), considerar bipartição.
# Clusters 28 e 30 podem ser agrupados. Distância: 0.10510102047890868, Soma das dispersões: 0.10947326931126641
# Cluster 28 tem alta dispersão (F_k), considerar bipartição.
# Clusters 30 e 5 podem ser agrupados. Distância: 0.19973636597322264, Soma das dispersões: 0.1676808989526013
# Cluster 30 tem alta dispersão (F_k), considerar bipartição.
# Cluster 30 tem alta dispersão (F_k), considerar bipartição.
# Cluster 30 tem alta dispersão (F_k), considerar bipartição.
# Clusters 30 e 28 podem ser agrupados. Distância: 0.10510102047890868, Soma das dispersões: 0.10947326931126641
# Cluster 30 tem alta dispersão (F_k), considerar bipartição.
# Cluster 30 tem alta dispersão (F_k), considerar bipartição.
# Clusters 30 e 42 podem ser agrupados. Distância: 0.18665512787973512, Soma das dispersões: 0.14069055477412346
# Cluster 31 tem alta dispersão (F_k), considerar bipartição.
# Cluster 31 tem alta dispersão (F_k), considerar bipartição.
# Cluster 31 tem alta dispersão (F_k), considerar bipartição.
# Cluster 31 tem alta dispersão (F_k), considerar bipartição.
# Cluster 31 tem alta dispersão (F_k), considerar bipartição.
# Cluster 31 tem alta dispersão (F_k), considerar bipartição.
# Cluster 32 tem alta dispersão (F_k), considerar bipartição.
# Cluster 32 tem alta dispersão (F_k), considerar bipartição.
# Clusters 32 e 24 podem ser agrupados. Distância: 0.12779541857432233, Soma das dispersões: 0.12293194112503716
# Cluster 32 tem alta dispersão (F_k), considerar bipartição.
# Cluster 32 tem alta dispersão (F_k), considerar bipartição.
# Clusters 32 e 34 podem ser agrupados. Distância: 0.13748708762582953, Soma das dispersões: 0.11368724434239977
# Cluster 32 tem alta dispersão (F_k), considerar bipartição.
# Cluster 32 tem alta dispersão (F_k), considerar bipartição.
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Clusters 33 e 24 podem ser agrupados. Distância: 0.16819482480440792, Soma das dispersões: 0.12803077722757011
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Clusters 33 e 34 podem ser agrupados. Distância: 0.14183279063966078, Soma das dispersões: 0.11878608044493272
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Cluster 34 tem alta dispersão (F_k), considerar bipartição.
# Cluster 34 tem alta dispersão (F_k), considerar bipartição.
# Cluster 34 tem alta dispersão (F_k), considerar bipartição.
# Cluster 34 tem alta dispersão (F_k), considerar bipartição.
# Clusters 34 e 32 podem ser agrupados. Distância: 0.13748708762582953, Soma das dispersões: 0.11368724434239977
# Clusters 34 e 33 podem ser agrupados. Distância: 0.14183279063966078, Soma das dispersões: 0.11878608044493272
# Cluster 34 tem alta dispersão (F_k), considerar bipartição.
# Cluster 34 tem alta dispersão (F_k), considerar bipartição.
# Cluster 39 tem alta dispersão (F_k), considerar bipartição.
# Cluster 39 tem alta dispersão (F_k), considerar bipartição.
# Cluster 39 tem alta dispersão (F_k), considerar bipartição.
# Clusters 42 e 5 podem ser agrupados. Distância: 0.1941747241405109, Soma das dispersões: 0.15488731705313347
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Clusters 42 e 30 podem ser agrupados. Distância: 0.18665512787973512, Soma das dispersões: 0.14069055477412346
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 44 tem alta dispersão (F_k), considerar bipartição.
# Cluster 44 tem alta dispersão (F_k), considerar bipartição.
# Cluster 44 tem alta dispersão (F_k), considerar bipartição.
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Clusters 57 e 25 podem ser agrupados. Distância: 0.16101787629568612, Soma das dispersões: 0.13931325453803636
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Cluster 58 tem alta dispersão (F_k), considerar bipartição.
# Cluster 58 tem alta dispersão (F_k), considerar bipartição.
# Cluster 58 tem alta dispersão (F_k), considerar bipartição.
# Cluster 58 tem alta dispersão (F_k), considerar bipartição.
# Cluster 58 tem alta dispersão (F_k), considerar bipartição.
# Cluster 58 tem alta dispersão (F_k), considerar bipartição.
# Cluster 5 tem população baixa e será agrupado com o cluster 42. Distância: 0.1941747241405109
# Cluster 6 tem população baixa e será agrupado com o cluster 57. Distância: 0.3201446186547476
# Cluster 10 tem população baixa e será agrupado com o cluster 58. Distância: 0.20507138658109197
# Cluster 13 tem população baixa e será agrupado com o cluster 30. Distância: 0.3421937811173727
# Cluster 26 tem população baixa e será agrupado com o cluster 57. Distância: 0.18981796237038062
# Cluster 28 tem população baixa e será agrupado com o cluster 30. Distância: 0.10510102047890868
# Cluster 38 tem população baixa e será agrupado com o cluster 57. Distância: 0.39571617030096984
# Cluster 39 tem população baixa e será agrupado com o cluster 57. Distância: 0.23836344347417607
# Cluster 44 tem população baixa e será agrupado com o cluster 58. Distância: 0.1919703212205234

# %%
# Agrupando os clusters proximos e com baixa população
for i in agrupamentos:
    cluster_index[cluster_index == i[0]] = i[1]

# Plotando os clusters novamente com os clusters agrupados
plt.figure(figsize=(8, 5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster=' + str(c), alpha=.7)

# Plotando centróides
i = False
for centroid in som.get_weights()[0]:
    if centroid[1] > min(data_normalized[:,1]) and centroid[0] > min(data_normalized[:,0]):
        centroid = scaler.inverse_transform([centroid])[0]
        plt.scatter(centroid[0], centroid[1], marker='x', 
                    s=10, linewidths=20, color='k', label='Centróide' if not i else None)
        i = True

plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();

# %%
data_normalized, data, n_0 = data_train_normalized, data_train, n_0_train

# Eu uso topografia linear som
som_shape = (1, int(5*np.sqrt(n_0)))

som = MiniSom(som_shape[0], som_shape[1], data_normalized.shape[1], sigma=0.5, learning_rate=0.5)

max_iter = 1000
q_error = []
t_error = []

for i in range(max_iter):
    rand_i = np.random.randint(len(data_normalized))
    som.update(data_normalized[rand_i], som.winner(data_normalized[rand_i]), i, max_iter)
    q_error.append(som.quantization_error(data_normalized))
    t_error.append(som.topographic_error(data_normalized))

plt.plot(np.arange(max_iter), q_error, label='erro de quantização')
plt.plot(np.arange(max_iter), t_error, label='erro topográfico')
plt.ylabel('Erro de quantização')
plt.xlabel('Índice de iteração')
plt.legend()
plt.show()

# %%
# cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Plotando os clusters 
plt.figure(figsize=(8,5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster='+str(c), alpha=.7)

# Plotando centróides
for centroid in som.get_weights():
    centroid = scaler.inverse_transform(centroid)
    plt.scatter(centroid[:,0], centroid[:, 1], marker='x', 
                s=10, linewidths=20, color='k', label='Centróide') # label='centróide'
    
plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();
plt.plot()

# Supondo que 'som', 'data_normalized', 'som_shape' e 'scaler' já estejam definidos no seu código

# Cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# Com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = data[cluster_index == c]
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(F_j)
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data, cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 0 10 18 19 20 21 33 36 40 41 42 43 44 45]
# F_out (Dispersão inter-cluster): 18972.441580378076
# F_in (Dispersão intra-cluster) por cluster: 7870.3817513368995
# Número de pontos por cluster: [5, 1, 16, 6, 22, 3, 1, 4, 1, 5, 6, 5, 17, 8]
# Centróides dos clusters: [array([108.8,  89. ]), array([18., 94.]), array([78.875 , 83.9375]), array([85.83333333, 34.83333333]), array([46.95454545, 51.        ]), array([103.,  13.]), array([137.,  18.]), array([19.75, 79.25]), array([126.,  28.]), array([28.2, 72. ]), array([27.        , 34.66666667]), array([24.8,  9.6]), array([61.70588235, 46.52941176]), array([78.125, 11.   ])]
# Máxima distância (diâmetro) por cluster: [40.496913462633174, 0.0, 28.319604517012593, 23.021728866442675, 25.45584412271571, 20.8806130178211, 0.0, 13.038404810405298, 0.0, 18.35755975068582, 26.40075756488817, 17.804493814764857, 19.6468827043885, 20.615528128088304]
# Variância intra-cluster por cluster: [255.76, 0.0, 114.54296875, 105.94444444444446, 65.04338842975207, 80.66666666666667, 0.0, 31.375000000000004, 0.0, 47.76, 104.55555555555554, 70.0, 34.69204152249135, 64.859375]
# Desvio padrão intra-cluster por cluster: [15.992498241363043, 0.0, 10.702474889015157, 10.292931771096342, 8.064948135589718, 8.981462390204987, 0.0, 5.60133912560202, 0.0, 6.910861017268398, 10.225241100118645, 8.366600265340756, 5.889995035863048, 8.053531833922307]

# %%
# removendo neuronios não treinados
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Plotando os clusters 
plt.figure(figsize=(8,5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster='+str(c), alpha=.7)

i=False
for centroid in som.get_weights()[0]:
    # Filtrando centróides próximos de 0
    if centroid[1] > min(data_normalized[:,1]) and centroid[0] > min(data_normalized[:,0]):  # Verifica se qualquer coordenada é maior que a tolerância
        centroid = scaler.inverse_transform([centroid])[0]
        plt.scatter(centroid[0], centroid[1], marker='x', 
                    s=10, linewidths=20, color='k', label='Centróide' if not i else None) # label='centróide'
        i = True
    
plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();
plt.plot()

# Supondo que 'som', 'data_normalized', 'som_shape' e 'scaler' já estejam definidos no seu código

# Cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# Com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = data_normalized[cluster_index == c]
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(float(F_j))
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data_normalized, cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {F_j_values}")
print(f"F_in (Dispersão intra-cluster): {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 0 10 18 19 20 21 33 36 40 41 42 43 44 45]
# F_out (Dispersão inter-cluster): 1.6375256534059517
# F_in (Dispersão intra-cluster) por cluster: [0.09062832431917942, 0.0, 0.17060628925904306, 0.04745304758807617, 0.12713098402901635, 0.017994539718265694, 0.0, 0.00928927776424722, 0.0, 0.01802746797455881, 0.04650061556282162, 0.028688536254441746, 0.0582281126276319, 0.045769926319089854]
# F_in (Dispersão intra-cluster): 0.6603171214163719
# Número de pontos por cluster: [5, 1, 16, 6, 22, 3, 1, 4, 1, 5, 6, 5, 17, 8]
# Centróides dos clusters: [array([0.76885246, 0.91666667]), array([0.02459016, 0.96875   ]), array([0.52356557, 0.86393229]), array([0.58060109, 0.35243056]), array([0.2619225 , 0.52083333]), array([0.72131148, 0.125     ]), array([1.        , 0.17708333]), array([0.03893443, 0.81510417]), array([0.90983607, 0.28125   ]), array([0.10819672, 0.73958333]), array([0.09836066, 0.35069444]), array([0.08032787, 0.08958333]), array([0.3828351 , 0.47426471]), array([0.51741803, 0.10416667])]
# Máxima distância (diâmetro) por cluster: [0.34392483487479664, 0.0, 0.27507908515655466, 0.1912421930386187, 0.23858875045481598, 0.17544442454292486, 0.0, 0.1112991114441729, 0.0, 0.1612102354258152, 0.22765898766880038, 0.1621660980857122, 0.2021154693508004, 0.20849682568556321]
# Variância intra-cluster por cluster: [0.018125664863835884, 0.0, 0.010662893078690191, 0.007908841264679362, 0.005778681092228016, 0.005998179906088565, 0.0, 0.002322319441061805, 0.0, 0.003605493594911762, 0.007750102593803603, 0.005737707250888349, 0.0034251830957430533, 0.005721240789886232]
# Desvio padrão intra-cluster por cluster: [0.13463158939801567, 0.0, 0.10326128547858675, 0.08893166626505634, 0.07601763671825122, 0.07744791737734827, 0.0, 0.048190449687275226, 0.0, 0.060045762505873485, 0.08803466700001542, 0.07574765508508068, 0.058525063825194186, 0.07563888411317443]

# %%
import numpy as np

# Função para calcular a distância entre dois pontos (centróides)
def calcular_distancia(centroid1, centroid2):
    return np.linalg.norm(centroid1 - centroid2)

# Função para decidir se clusters devem ser agrupados ou bipartidos
def verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points ,threshold=2, population_threshold = 5):
    n_clusters = len(centroid_values)
    agrupamentos = []  # Lista para armazenar decisões de agrupamento
    
    for i in range(n_clusters):
        for j in range(n_clusters):
            if i == j or (i,j) in agrupamentos:
                continue
            # Calcular a distância entre os centróides dos clusters i e j
            dist = calcular_distancia(centroid_values[i], centroid_values[j])

            sigma_sum = sigma_values[i] + sigma_values[j]
            
            # Comparar a distância entre centróides com a soma das dispersões
            if dist < sigma_sum * threshold:  # Se a distância for muito pequena, agrupar
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[j]))  # Armazenar os pares de clusters que devem ser agrupados
                print(f"Clusters {np.unique(cluster_index)[i]} e {np.unique(cluster_index)[j]} podem ser agrupados. Distância: {dist}, Soma das dispersões: {sigma_sum}")
            elif F_values[i] > F_values[j] and F_values[i] > 10 * F_values[j]:  # Se F_k for muito maior em um cluster
                print(f"Cluster {np.unique(cluster_index)[i]} tem alta dispersão (F_k), considerar bipartição.")
    for i in range(n_clusters):
        if n_cluster_points[i] < population_threshold:
            # Encontrar o cluster mais próximo para agrupar
            min_dist = float('inf')
            closest_cluster = None
            for j in range(n_clusters):
                if i != j and n_cluster_points[j] >= population_threshold:  # Não agrupar com clusters de baixa população
                    dist = calcular_distancia(centroid_values[i], centroid_values[j])
                    if dist < min_dist:
                        min_dist = dist
                        closest_cluster = j
            
            if closest_cluster is not None:
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[closest_cluster]))
                print(f"Cluster {np.unique(cluster_index)[i]} tem população baixa e será agrupado com o cluster {np.unique(cluster_index)[closest_cluster]}. Distância: {min_dist}")

        
    
    return agrupamentos

# Exemplo de centróides, dispersões e sigma (desvio padrão)
centroid_values = centroid_values

# Exemplo de dispersão F (somatória da distância intra-cluster)
F_values = F_j_values

# Exemplo de desvio padrão intra-cluster (σ)
sigma_values = desvio_padrao_intra_values

# Chamando a função para verificar agrupamento e bipartição
agrupamentos = verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points_values, 1.4, 7)

# Se necessário, implementar a lógica de bipartição para clusters com alta dispersão F_k
# Out:
# Cluster 0 tem alta dispersão (F_k), considerar bipartição.
# Clusters 0 e 18 podem ser agrupados. Distância: 0.25089155103406086, Soma das dispersões: 0.23789287487660243
# Cluster 0 tem alta dispersão (F_k), considerar bipartição.
# Cluster 0 tem alta dispersão (F_k), considerar bipartição.
# Clusters 18 e 0 podem ser agrupados. Distância: 0.25089155103406086, Soma das dispersões: 0.23789287487660243
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Cluster 19 tem alta dispersão (F_k), considerar bipartição.
# Cluster 19 tem alta dispersão (F_k), considerar bipartição.
# Cluster 19 tem alta dispersão (F_k), considerar bipartição.
# Cluster 20 tem alta dispersão (F_k), considerar bipartição.
# Cluster 20 tem alta dispersão (F_k), considerar bipartição.
# Cluster 20 tem alta dispersão (F_k), considerar bipartição.
# Cluster 20 tem alta dispersão (F_k), considerar bipartição.
# Clusters 20 e 44 podem ser agrupados. Distância: 0.12957041831990868, Soma das dispersões: 0.13454270054344541
# Cluster 21 tem alta dispersão (F_k), considerar bipartição.
# Cluster 21 tem alta dispersão (F_k), considerar bipartição.
# Cluster 21 tem alta dispersão (F_k), considerar bipartição.
# Clusters 21 e 45 podem ser agrupados. Distância: 0.20495502853654585, Soma das dispersões: 0.1530868014905227
# Cluster 36 tem alta dispersão (F_k), considerar bipartição.
# Cluster 36 tem alta dispersão (F_k), considerar bipartição.
# Cluster 36 tem alta dispersão (F_k), considerar bipartição.
# Clusters 36 e 41 podem ser agrupados. Distância: 0.10247273680049049, Soma das dispersões: 0.10823621219314872
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Clusters 41 e 36 podem ser agrupados. Distância: 0.10247273680049049, Soma das dispersões: 0.10823621219314872
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 43 tem alta dispersão (F_k), considerar bipartição.
# Cluster 43 tem alta dispersão (F_k), considerar bipartição.
# Cluster 43 tem alta dispersão (F_k), considerar bipartição.
# Cluster 44 tem alta dispersão (F_k), considerar bipartição.
# Clusters 44 e 20 podem ser agrupados. Distância: 0.12957041831990868, Soma das dispersões: 0.13454270054344541
# Cluster 44 tem alta dispersão (F_k), considerar bipartição.
# Cluster 44 tem alta dispersão (F_k), considerar bipartição.
# Cluster 45 tem alta dispersão (F_k), considerar bipartição.
# Clusters 45 e 21 podem ser agrupados. Distância: 0.20495502853654585, Soma das dispersões: 0.1530868014905227
# Cluster 45 tem alta dispersão (F_k), considerar bipartição.
# Cluster 45 tem alta dispersão (F_k), considerar bipartição.
# Cluster 0 tem população baixa e será agrupado com o cluster 18. Distância: 0.25089155103406086
# Cluster 10 tem população baixa e será agrupado com o cluster 20. Distância: 0.5069082557905498
# Cluster 19 tem população baixa e será agrupado com o cluster 44. Distância: 0.23228204329266885
# Cluster 21 tem população baixa e será agrupado com o cluster 45. Distância: 0.20495502853654585
# Cluster 33 tem população baixa e será agrupado com o cluster 45. Distância: 0.48805962274814085
# Cluster 36 tem população baixa e será agrupado com o cluster 20. Distância: 0.36921403827072824
# Cluster 40 tem população baixa e será agrupado com o cluster 45. Distância: 0.4305234249152691
# Cluster 41 tem população baixa e será agrupado com o cluster 20. Distância: 0.2673633832051256
# Cluster 42 tem população baixa e será agrupado com o cluster 20. Distância: 0.23600788043965956
# Cluster 43 tem população baixa e será agrupado com o cluster 45. Distância: 0.437333379722306

# %%
# Agrupando os clusters proximos e com baixa população
for i in agrupamentos:
    cluster_index[cluster_index == i[0]] = i[1]

# Plotando os clusters novamente com os clusters agrupados
plt.figure(figsize=(8, 5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster=' + str(c), alpha=.7)

# Plotando centróides
i = False
for centroid in som.get_weights()[0]:
    if centroid[1] > min(data_normalized[:,1]) and centroid[0] > min(data_normalized[:,0]):
        centroid = scaler.inverse_transform([centroid])[0]
        plt.scatter(centroid[0], centroid[1], marker='x', 
                    s=10, linewidths=20, color='k', label='Centróide' if not i else None)
        i = True

plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();

# %%
# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = scaler.transform(data[cluster_index == c])
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(F_j)
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, scaler.transform(data), cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [18 20 44 45]
# F_out (Dispersão inter-cluster): 0.0
# F_in (Dispersão intra-cluster) por cluster: 4.127652665404159
# Número de pontos por cluster: [21, 55, 6, 18]
# Centróides dos clusters: [array([0.58196721, 0.8764881 ]), array([0.24694486, 0.53731061]), array([0.58060109, 0.35243056]), array([0.47859745, 0.11747685])]
# Máxima distância (diâmetro) por cluster: [0.5635721953728857, 0.7087209478728393, 0.1912421930386187, 0.9797526585074033]
# Variância intra-cluster por cluster: [0.023858622484273943, 0.036566479793753666, 0.007908841264679362, 0.08711178649943767]
# Desvio padrão intra-cluster por cluster: [0.15446236591569462, 0.19122363816681678, 0.08893166626505634, 0.29514705910687583]

# %%
data_normalized, data, n_0 = data_val_normalized, data_val, n_0_val

# Eu uso topografia linear som
som_shape = (1, int(5*np.sqrt(n_0)))

som = MiniSom(som_shape[0], som_shape[1], data_normalized.shape[1], sigma=0.5, learning_rate=0.5)

max_iter = 1000
q_error = []
t_error = []

for i in range(max_iter):
    rand_i = np.random.randint(len(data_normalized))
    som.update(data_normalized[rand_i], som.winner(data_normalized[rand_i]), i, max_iter)
    q_error.append(som.quantization_error(data_normalized))
    t_error.append(som.topographic_error(data_normalized))

plt.plot(np.arange(max_iter), q_error, label='erro de quantização')
plt.plot(np.arange(max_iter), t_error, label='erro topográfico')
plt.ylabel('Erro de quantização')
plt.xlabel('Índice de iteração')
plt.legend()
plt.show()

# %%
# cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Plotando os clusters 
plt.figure(figsize=(8,5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster='+str(c), alpha=.7)

# Plotando centróides
for centroid in som.get_weights():
    centroid = scaler.inverse_transform(centroid)
    plt.scatter(centroid[:,0], centroid[:, 1], marker='x', 
                s=10, linewidths=20, color='k', label='Centróide') # label='centróide'
    
plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();
plt.plot()

# Supondo que 'som', 'data_normalized', 'som_shape' e 'scaler' já estejam definidos no seu código

# Cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# Com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = data[cluster_index == c]
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(F_j)
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data, cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 0  1  6  9 12 15 17 18 24 36 39 45 46 47 49]
# F_out (Dispersão inter-cluster): 34882.429574682785
# F_in (Dispersão intra-cluster) por cluster: 5466.816615737204
# Número de pontos por cluster: [14, 5, 17, 5, 6, 2, 3, 2, 4, 4, 7, 7, 11, 12, 1]
# Centróides dos clusters: [array([62.5       , 54.14285714]), array([29.6, 31.6]), array([48.29411765, 52.29411765]), array([28.4, 93.6]), array([76.83333333, 89.66666667]), array([102. ,  68.5]), array([86.66666667, 69.        ]), array([123. ,  76.5]), array([73.75, 73.75]), array([105.5,  19.5]), array([26.57142857, 72.42857143]), array([24.42857143,  9.57142857]), array([63.18181818, 40.        ]), array([79.91666667, 12.5       ]), array([103.,  85.])]
# Máxima distância (diâmetro) por cluster: [15.033296378372908, 18.35755975068582, 19.026297590440446, 20.248456731316587, 16.278820596099706, 2.23606797749979, 12.165525060596439, 7.810249675906654, 8.94427190999916, 22.02271554554524, 24.596747752497688, 21.095023109728988, 20.615528128088304, 25.96150997149434, 0.0]
# Variância intra-cluster por cluster: [30.086734693877556, 66.47999999999999, 45.238754325259514, 65.67999999999999, 43.36111111111111, 1.2500000000000002, 25.555555555555557, 15.249999999999998, 11.875, 89.5, 102.48979591836735, 64.20408163265306, 61.96694214876033, 82.65972222222221, 0.0]
# Desvio padrão intra-cluster por cluster: [5.485137618499426, 8.153526844255802, 6.725976087175713, 8.104319835741924, 6.584915421712803, 1.118033988749895, 5.055250296034367, 3.905124837953327, 3.4460121880225554, 9.460443964212251, 10.123724409443756, 8.012744949931518, 7.8719084184688235, 9.091739229774587, 0.0]

# %%
# removendo neuronios não treinados
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Plotando os clusters 
plt.figure(figsize=(8,5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster='+str(c), alpha=.7)

i=False
for centroid in som.get_weights()[0]:
    # Filtrando centróides próximos de 0
    if centroid[1] > min(data_normalized[:,1]) and centroid[0] > min(data_normalized[:,0]):  # Verifica se qualquer coordenada é maior que a tolerância
        centroid = scaler.inverse_transform([centroid])[0]
        plt.scatter(centroid[0], centroid[1], marker='x', 
                    s=10, linewidths=20, color='k', label='Centróide' if not i else None) # label='centróide'
        i = True
    
plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();
plt.plot()

# Supondo que 'som', 'data_normalized', 'som_shape' e 'scaler' já estejam definidos no seu código

# Cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# Com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = data_normalized[cluster_index == c]
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(float(F_j))
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data_normalized, cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {F_j_values}")
print(f"F_in (Dispersão intra-cluster): {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 0  1  6  9 12 15 17 18 24 36 39 45 46 47 49]
# F_out (Dispersão inter-cluster): 2.9357265669632104
# F_in (Dispersão intra-cluster) por cluster: [0.036221573488416266, 0.025192098991459886, 0.06974919428657878, 0.026080333747648454, 0.021584143456309043, 0.0001886259527382136, 0.008126035787870646, 0.002565689130199468, 0.0038008267990048915, 0.02673851978448149, 0.06124686497538639, 0.03770397822525946, 0.057614305893183365, 0.09279915723259877, 0.0]
# F_in (Dispersão intra-cluster): 0.4696113477511351
# Número de pontos por cluster: [14, 5, 17, 5, 6, 2, 3, 2, 4, 4, 7, 7, 11, 12, 1]
# Centróides dos clusters: [array([0.38934426, 0.55357143]), array([0.11967213, 0.31875   ]), array([0.2729026 , 0.53431373]), array([0.10983607, 0.96458333]), array([0.5068306 , 0.92361111]), array([0.71311475, 0.703125  ]), array([0.58743169, 0.70833333]), array([0.8852459 , 0.78645833]), array([0.48155738, 0.7578125 ]), array([0.74180328, 0.19270833]), array([0.09484778, 0.74404762]), array([0.07728337, 0.08928571]), array([0.39493294, 0.40625   ]), array([0.53210383, 0.11979167]), array([0.72131148, 0.875     ])]
# Máxima distância (diâmetro) por cluster: [0.13007150945236787, 0.1612102354258152, 0.19808632760668382, 0.17196241743739832, 0.14115565655159448, 0.019422973651746202, 0.12607039684649202, 0.07163363916763503, 0.07769189460698454, 0.18062847845595706, 0.21365271016920762, 0.18680921315975882, 0.20463351149261824, 0.26666264464753875, 0.0]
# Variância intra-cluster por cluster: [0.0025872552491725902, 0.005038419798291977, 0.004102893781563457, 0.005216066749529691, 0.003597357242718174, 9.43129763691068e-05, 0.002708678595956882, 0.001282844565099734, 0.0009502066997512229, 0.006684629946120372, 0.008749552139340913, 0.005386282603608495, 0.005237664172107579, 0.007733263102716564, 0.0]
# Desvio padrão intra-cluster por cluster: [0.05086506904716232, 0.07098182723973775, 0.06405383502619852, 0.07222234245390889, 0.05997797297940448, 0.009711486825873101, 0.05204496705692955, 0.035816819583817515, 0.03082542294521233, 0.08175958626436641, 0.09353904072279613, 0.07339129787385215, 0.07237170836803274, 0.08793897374154741, 0.0]

# %%
import numpy as np

# Função para calcular a distância entre dois pontos (centróides)
def calcular_distancia(centroid1, centroid2):
    return np.linalg.norm(centroid1 - centroid2)

# Função para decidir se clusters devem ser agrupados ou bipartidos
def verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points ,threshold=2, population_threshold = 5):
    n_clusters = len(centroid_values)
    agrupamentos = []  # Lista para armazenar decisões de agrupamento
    
    for i in range(n_clusters):
        for j in range(n_clusters):
            if i == j or (i,j) in agrupamentos:
                continue
            # Calcular a distância entre os centróides dos clusters i e j
            dist = calcular_distancia(centroid_values[i], centroid_values[j])

            sigma_sum = sigma_values[i] + sigma_values[j]
            
            # Comparar a distância entre centróides com a soma das dispersões
            if dist < sigma_sum * threshold:  # Se a distância for muito pequena, agrupar
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[j]))  # Armazenar os pares de clusters que devem ser agrupados
                print(f"Clusters {np.unique(cluster_index)[i]} e {np.unique(cluster_index)[j]} podem ser agrupados. Distância: {dist}, Soma das dispersões: {sigma_sum}")
            elif F_values[i] > F_values[j] and F_values[i] > 10 * F_values[j]:  # Se F_k for muito maior em um cluster
                print(f"Cluster {np.unique(cluster_index)[i]} tem alta dispersão (F_k), considerar bipartição.")
    for i in range(n_clusters):
        if n_cluster_points[i] < population_threshold:
            # Encontrar o cluster mais próximo para agrupar
            min_dist = float('inf')
            closest_cluster = None
            for j in range(n_clusters):
                if i != j and n_cluster_points[j] >= population_threshold:  # Não agrupar com clusters de baixa população
                    dist = calcular_distancia(centroid_values[i], centroid_values[j])
                    if dist < min_dist:
                        min_dist = dist
                        closest_cluster = j
            
            if closest_cluster is not None:
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[closest_cluster]))
                print(f"Cluster {np.unique(cluster_index)[i]} tem população baixa e será agrupado com o cluster {np.unique(cluster_index)[closest_cluster]}. Distância: {min_dist}")

        
    
    return agrupamentos

# Exemplo de centróides, dispersões e sigma (desvio padrão)
centroid_values = centroid_values

# Exemplo de dispersão F (somatória da distância intra-cluster)
F_values = F_j_values

# Exemplo de desvio padrão intra-cluster (σ)
sigma_values = desvio_padrao_intra_values

# Chamando a função para verificar agrupamento e bipartição
agrupamentos = verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points_values, 1.4, 7)

# Se necessário, implementar a lógica de bipartição para clusters com alta dispersão F_k
# Out:
# Clusters 0 e 6 podem ser agrupados. Distância: 0.11802338324512365, Soma das dispersões: 0.11491890407336083
# Cluster 0 tem alta dispersão (F_k), considerar bipartição.
# Cluster 0 tem alta dispersão (F_k), considerar bipartição.
# Clusters 0 e 46 podem ser agrupados. Distância: 0.14742739429690044, Soma das dispersões: 0.12323677741519506
# Cluster 0 tem alta dispersão (F_k), considerar bipartição.
# Cluster 1 tem alta dispersão (F_k), considerar bipartição.
# Cluster 1 tem alta dispersão (F_k), considerar bipartição.
# Clusters 6 e 0 podem ser agrupados. Distância: 0.11802338324512365, Soma das dispersões: 0.11491890407336083
# Cluster 6 tem alta dispersão (F_k), considerar bipartição.
# Cluster 6 tem alta dispersão (F_k), considerar bipartição.
# Cluster 6 tem alta dispersão (F_k), considerar bipartição.
# Clusters 6 e 46 podem ser agrupados. Distância: 0.1768946572850421, Soma das dispersões: 0.13642554339423124
# Cluster 6 tem alta dispersão (F_k), considerar bipartição.
# Cluster 9 tem alta dispersão (F_k), considerar bipartição.
# Cluster 9 tem alta dispersão (F_k), considerar bipartição.
# Clusters 9 e 39 podem ser agrupados. Distância: 0.2210444528246949, Soma das dispersões: 0.16576138317670502
# Cluster 9 tem alta dispersão (F_k), considerar bipartição.
# Cluster 12 tem alta dispersão (F_k), considerar bipartição.
# Cluster 12 tem alta dispersão (F_k), considerar bipartição.
# Cluster 15 tem alta dispersão (F_k), considerar bipartição.
# Cluster 17 tem alta dispersão (F_k), considerar bipartição.
# Cluster 17 tem alta dispersão (F_k), considerar bipartição.
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Cluster 24 tem alta dispersão (F_k), considerar bipartição.
# Cluster 24 tem alta dispersão (F_k), considerar bipartição.
# Cluster 36 tem alta dispersão (F_k), considerar bipartição.
# Cluster 36 tem alta dispersão (F_k), considerar bipartição.
# Clusters 36 e 47 podem ser agrupados. Distância: 0.22201509204950123, Soma das dispersões: 0.16969856000591382
# Cluster 36 tem alta dispersão (F_k), considerar bipartição.
# Clusters 39 e 9 podem ser agrupados. Distância: 0.2210444528246949, Soma das dispersões: 0.16576138317670502
# Cluster 39 tem alta dispersão (F_k), considerar bipartição.
# Cluster 39 tem alta dispersão (F_k), considerar bipartição.
# Cluster 39 tem alta dispersão (F_k), considerar bipartição.
# Cluster 39 tem alta dispersão (F_k), considerar bipartição.
# Cluster 45 tem alta dispersão (F_k), considerar bipartição.
# Cluster 45 tem alta dispersão (F_k), considerar bipartição.
# Cluster 45 tem alta dispersão (F_k), considerar bipartição.
# Clusters 46 e 0 podem ser agrupados. Distância: 0.14742739429690044, Soma das dispersões: 0.12323677741519506
# Clusters 46 e 6 podem ser agrupados. Distância: 0.1768946572850421, Soma das dispersões: 0.13642554339423124
# Cluster 46 tem alta dispersão (F_k), considerar bipartição.
# Cluster 46 tem alta dispersão (F_k), considerar bipartição.
# Cluster 46 tem alta dispersão (F_k), considerar bipartição.
# Cluster 46 tem alta dispersão (F_k), considerar bipartição.
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Clusters 47 e 36 podem ser agrupados. Distância: 0.22201509204950123, Soma das dispersões: 0.16969856000591382
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Cluster 1 tem população baixa e será agrupado com o cluster 45. Distância: 0.23334666333475393
# Cluster 9 tem população baixa e será agrupado com o cluster 39. Distância: 0.2210444528246949
# Cluster 12 tem população baixa e será agrupado com o cluster 0. Distância: 0.3882427159113018
# Cluster 15 tem população baixa e será agrupado com o cluster 0. Distância: 0.3566421204647282
# Cluster 17 tem população baixa e será agrupado com o cluster 0. Distância: 0.25137596894025815
# Cluster 18 tem população baixa e será agrupado com o cluster 0. Distância: 0.5478638027045657
# Cluster 24 tem população baixa e será agrupado com o cluster 0. Distância: 0.22409300254792275
# Cluster 36 tem população baixa e será agrupado com o cluster 47. Distância: 0.22201509204950123
# Cluster 49 tem população baixa e será agrupado com o cluster 0. Distância: 0.4620806824719994

# %%
# Agrupando os clusters proximos e com baixa população
for i in agrupamentos:
    cluster_index[cluster_index == i[0]] = i[1]

# Plotando os clusters novamente com os clusters agrupados
plt.figure(figsize=(8, 5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster=' + str(c), alpha=.7)

# Plotando centróides
i = False
for centroid in som.get_weights()[0]:
    if centroid[1] > min(data_normalized[:,1]) and centroid[0] > min(data_normalized[:,0]):
        centroid = scaler.inverse_transform([centroid])[0]
        plt.scatter(centroid[0], centroid[1], marker='x', 
                    s=10, linewidths=20, color='k', label='Centróide' if not i else None)
        i = True

plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();

# %%
# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = scaler.transform(data[cluster_index == c])
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(F_j)
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, scaler.transform(data), cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 0 39 45 47]
# F_out (Dispersão inter-cluster): 2.3475116664466507
# F_in (Dispersão intra-cluster) por cluster: 3.5922117568377563
# Número de pontos por cluster: [60, 12, 12, 16]
# Centróides dos clusters: [array([0.41803279, 0.59756944]), array([0.1010929, 0.8359375]), array([0.09494536, 0.18489583]), array([0.58452869, 0.13802083])]
# Máxima distância (diâmetro) por cluster: [0.7622401666386577, 0.40264887090202467, 0.3649626982261056, 0.40500226724125576]
# Variância intra-cluster por cluster: [0.04788756717716806, 0.019153119021085588, 0.01847587647035998, 0.016713111269395366]
# Desvio padrão intra-cluster por cluster: [0.21883228093032356, 0.13839479405340935, 0.13592599630078117, 0.12927919890452355]

# %% [markdown]
# ## ART

# %%
import numpy as np

class ART2:
    def __init__(self, input_dim, num_clusters, vigilance=0.9, learning_rate=0.5):
        self.input_dim = input_dim
        self.num_clusters = num_clusters
        self.vigilance = vigilance
        self.learning_rate = learning_rate
        
        # Inicializar pesos com valores aleatórios
        self.weights = np.random.rand(num_clusters, input_dim)
    
    def normalize(self, vector):
        return vector / (np.linalg.norm(vector) + 1e-9)
    
    def match(self, input_vector, cluster_idx):
        cluster_vector = self.weights[cluster_idx]
        return np.dot(input_vector, cluster_vector) / np.linalg.norm(cluster_vector)
    
    def train(self, data):
        for input_vector in data:
            input_vector = self.normalize(input_vector)
            
            # Testar similaridade com os clusters existentes
            for cluster_idx in range(self.num_clusters):
                similarity = self.match(input_vector, cluster_idx)
                if similarity >= self.vigilance:
                    # Atualizar os pesos do cluster
                    self.weights[cluster_idx] += self.learning_rate * (input_vector - self.weights[cluster_idx])
                    self.weights[cluster_idx] = self.normalize(self.weights[cluster_idx])
                    break
            else:
                print("Nenhum cluster correspondeu ao critério de vigilância.")
    
    def predict(self, data):
        predictions = []
        for input_vector in data:
            input_vector = self.normalize(input_vector)
            similarities = [self.match(input_vector, cluster_idx) for cluster_idx in range(self.num_clusters)]
            predictions.append(np.argmax(similarities))
        return predictions

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Função para calcular a dispersão intra-cluster F_j
def calcular_dispersaointra(cluster_points, centroid):
    return np.sum(np.linalg.norm(cluster_points - centroid, axis=1))

# Função para calcular o diâmetro máximo do cluster
def calcular_diametro(cluster_points):
    distancias = [np.linalg.norm(point1 - point2) 
                  for i, point1 in enumerate(cluster_points) 
                  for j, point2 in enumerate(cluster_points) if i != j]
    return np.max(distancias)

# Função para calcular a variância intra-cluster
def calcular_variancia_intra(cluster_points, centroid):
    return np.var(np.linalg.norm(cluster_points - centroid, axis=1))

# Função para calcular o desvio padrão intra-cluster
def calcular_desvio_padrao_intra(variancia_intra):
    return np.sqrt(variancia_intra)

# Função para calcular a dispersão inter-cluster (F_out)
def calcular_dispersaointer(centroid_values, data_normalized, cluster_index, n_clusters):
    F_out_values = []
    for i in range(n_clusters):
        centroid_i = centroid_values[i]
        distancias = [np.linalg.norm(centroid_i - centroid_values[j]) for j in range(n_clusters) if i != j]
        F_out_values.append(np.mean(distancias))
    return np.mean(F_out_values)

data_normalized, data, n_0 = data_all_normalized, data_all, n_0_all
# Inicializando o ART2 com 2 dimensões e 5 clusters
art2 = ART2(input_dim=2, num_clusters=9, vigilance=0.3, learning_rate=0.6)
art2.train(data_normalized)
cluster_assignments = art2.predict(data_normalized)  # Clusters atribuídos

# Plotando os clusters
plt.figure(figsize=(8, 5))

unique_clusters = np.unique(cluster_assignments)
for cluster in unique_clusters:
    cluster_data = data_normalized[np.array(cluster_assignments) == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], 
                label=f'Cluster {cluster + 1}', alpha=0.7)

# Plotando centróides (os pesos dos clusters)
centroids = art2.weights
plt.scatter(centroids[:,0], centroids[:,1], marker='x', 
            s=100, linewidths=2, color='k', label='Centróide')

plt.title("Clusters gerados pela ART 2")
plt.xlabel("Dimensão 1")
plt.ylabel("Dimensão 2")
plt.legend()
plt.show()

# Inicializando as listas para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for cluster in unique_clusters:
    cluster_points = data_normalized[cluster_assignments == cluster]
    
    # Determinando o centróide do cluster (peso do cluster)
    centroid = art2.weights[cluster]
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(float(F_j))
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data_normalized, cluster_assignments, len(unique_clusters))

# Printando as métricas
print("Métricas para os clusters ART:")
print(f"Clusters: {unique_clusters}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {F_j_values}")
print(f"F_in (Dispersão intra-cluster): {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters ART:
# Clusters: [0 1 2 3 4 5 6 7 8]
# F_out (Dispersão inter-cluster): 0.5946543841483772
# F_in (Dispersão intra-cluster) por cluster: [3.2291574008318977, 4.553711859331308, 21.22393477792126, 3.616092406595679, 0.8674140090443314, 19.130710992733324, 4.0439944683579405, 0.8352542098916497, 16.965273376817002]
# F_in (Dispersão intra-cluster): 74.4655435015244
# Número de pontos por cluster: [7, 28, 52, 5, 6, 52, 8, 9, 33]
# Centróides dos clusters: [array([0.84719486, 0.53128228]), array([0.55289955, 0.15476404]), array([0.71966189, 0.82466555]), array([0.86015957, 0.895324  ]), array([0.53209518, 0.26259759]), array([0.15956849, 0.34750565]), array([0.99297927, 0.96792409]), array([0.26453453, 0.6101881 ]), array([0.03431915, 0.13869884])]
# Máxima distância (diâmetro) por cluster: [0.7553919099720151, 0.8890908985165115, 1.0624303551175136, 0.3827747511074903, 0.6537545655652791, 1.0817359575688579, 1.1150282225712835, 0.3268604997365618, 0.9690620406673258]
# Variância intra-cluster por cluster: [0.04742746636479483, 0.015451582967747322, 0.034650156633013525, 0.021272991408571224, 0.026842277249920388, 0.04807001013659417, 0.12006123690638612, 0.008606701363800326, 0.07100418946650819]
# Desvio padrão intra-cluster por cluster: [0.21777848003141823, 0.12430439641359159, 0.18614552541765145, 0.1458526359328868, 0.16383612925701213, 0.21924874033068964, 0.3464985381013694, 0.0927723092512002, 0.26646611316733726]

# %%
import numpy as np
cluster_index = [i+1 for i in cluster_assignments]
# Função para calcular a distância entre dois pontos (centróides)
def calcular_distancia(centroid1, centroid2):
    return np.linalg.norm(centroid1 - centroid2)

# Função para decidir se clusters devem ser agrupados ou bipartidos
def verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points ,threshold=2, population_threshold = 5):
    n_clusters = len(centroid_values)
    agrupamentos = []  # Lista para armazenar decisões de agrupamento
    
    for i in range(n_clusters):
        for j in range(n_clusters):
            if i == j or (i,j) in agrupamentos:
                continue
            # Calcular a distância entre os centróides dos clusters i e j
            dist = calcular_distancia(centroid_values[i], centroid_values[j])

            sigma_sum = sigma_values[i] + sigma_values[j]
            
            # Comparar a distância entre centróides com a soma das dispersões
            if dist < sigma_sum * threshold:  # Se a distância for muito pequena, agrupar
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[j]))  # Armazenar os pares de clusters que devem ser agrupados
                print(f"Clusters {np.unique(cluster_index)[i]} e {np.unique(cluster_index)[j]} podem ser agrupados. Distância: {dist}, Soma das dispersões: {sigma_sum}")
            elif F_values[i] > F_values[j] and F_values[i] > 10 * F_values[j]:  # Se F_k for muito maior em um cluster
                print(f"Cluster {np.unique(cluster_index)[i]} tem alta dispersão (F_k), considerar bipartição.")
    for i in range(n_clusters):
        if n_cluster_points[i] < population_threshold:
            # Encontrar o cluster mais próximo para agrupar
            min_dist = float('inf')
            closest_cluster = None
            for j in range(n_clusters):
                if i != j and n_cluster_points[j] >= population_threshold:  # Não agrupar com clusters de baixa população
                    dist = calcular_distancia(centroid_values[i], centroid_values[j])
                    if dist < min_dist:
                        min_dist = dist
                        closest_cluster = j
            
            if closest_cluster is not None:
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[closest_cluster]))
                print(f"Cluster {np.unique(cluster_index)[i]} tem população baixa e será agrupado com o cluster {np.unique(cluster_index)[closest_cluster]}. Distância: {min_dist}")

        
    
    return agrupamentos

# Exemplo de centróides, dispersões e sigma (desvio padrão)
centroid_values = centroid_values

# Exemplo de dispersão F (somatória da distância intra-cluster)
F_values = F_j_values

# Exemplo de desvio padrão intra-cluster (σ)
sigma_values = desvio_padrao_intra_values

# Chamando a função para verificar agrupamento e bipartição
agrupamentos = verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points_values, 1.5, 9)

# Se necessário, implementar a lógica de bipartição para clusters com alta dispersão F_k
# Out:
# Clusters 1 e 2 podem ser agrupados. Distância: 0.4778867178421696, Soma das dispersões: 0.3420828764450098
# Clusters 1 e 3 podem ser agrupados. Distância: 0.3199037461315603, Soma das dispersões: 0.4039240054490697
# Clusters 1 e 4 podem ser agrupados. Distância: 0.3642725091166518, Soma das dispersões: 0.36363111596430503
# Clusters 1 e 5 podem ser agrupados. Distância: 0.41410055916317967, Soma das dispersões: 0.3816146092884304
# Clusters 1 e 7 podem ser agrupados. Distância: 0.46033592711335863, Soma das dispersões: 0.5642770181327876
# Clusters 2 e 1 podem ser agrupados. Distância: 0.4778867178421696, Soma das dispersões: 0.3420828764450098
# Clusters 2 e 9 podem ser agrupados. Distância: 0.5188291865233315, Soma das dispersões: 0.39077050958092885
# Clusters 3 e 1 podem ser agrupados. Distância: 0.3199037461315603, Soma das dispersões: 0.4039240054490697
# Clusters 3 e 4 podem ser agrupados. Distância: 0.1572647885961067, Soma das dispersões: 0.3319981613505383
# Cluster 3 tem alta dispersão (F_k), considerar bipartição.
# Clusters 3 e 7 podem ser agrupados. Distância: 0.30858612917340034, Soma das dispersões: 0.5326440635190208
# Cluster 3 tem alta dispersão (F_k), considerar bipartição.
# Clusters 4 e 1 podem ser agrupados. Distância: 0.3642725091166518, Soma das dispersões: 0.36363111596430503
# Clusters 4 e 3 podem ser agrupados. Distância: 0.1572647885961067, Soma das dispersões: 0.3319981613505383
# Clusters 4 e 7 podem ser agrupados. Distância: 0.15136659622536414, Soma das dispersões: 0.4923511740342562
# Clusters 5 e 1 podem ser agrupados. Distância: 0.41410055916317967, Soma das dispersões: 0.3816146092884304
# Clusters 5 e 6 podem ser agrupados. Distância: 0.38208050129327226, Soma das dispersões: 0.38308486958770177
# Clusters 5 e 9 podem ser agrupados. Distância: 0.5129638184971442, Soma das dispersões: 0.4303022424243494
# Clusters 6 e 5 podem ser agrupados. Distância: 0.38208050129327226, Soma das dispersões: 0.38308486958770177
# Clusters 6 e 8 podem ser agrupados. Distância: 0.2828779569261347, Soma das dispersões: 0.3120210495818898
# Clusters 6 e 9 podem ser agrupados. Distância: 0.2434906219748274, Soma das dispersões: 0.4857148534980269
# Clusters 7 e 1 podem ser agrupados. Distância: 0.46033592711335863, Soma das dispersões: 0.5642770181327876
# Clusters 7 e 3 podem ser agrupados. Distância: 0.30858612917340034, Soma das dispersões: 0.5326440635190208
# Clusters 7 e 4 podem ser agrupados. Distância: 0.15136659622536414, Soma das dispersões: 0.4923511740342562
# Clusters 8 e 6 podem ser agrupados. Distância: 0.2828779569261347, Soma das dispersões: 0.3120210495818898
# Clusters 8 e 9 podem ser agrupados. Distância: 0.5246915720140972, Soma das dispersões: 0.35923842241853743
# Clusters 9 e 2 podem ser agrupados. Distância: 0.5188291865233315, Soma das dispersões: 0.39077050958092885
# Clusters 9 e 5 podem ser agrupados. Distância: 0.5129638184971442, Soma das dispersões: 0.4303022424243494
# Clusters 9 e 6 podem ser agrupados. Distância: 0.2434906219748274, Soma das dispersões: 0.4857148534980269
# Clusters 9 e 8 podem ser agrupados. Distância: 0.5246915720140972, Soma das dispersões: 0.35923842241853743
# Cluster 1 tem população baixa e será agrupado com o cluster 3. Distância: 0.3199037461315603
# Cluster 4 tem população baixa e será agrupado com o cluster 3. Distância: 0.1572647885961067
# Cluster 5 tem população baixa e será agrupado com o cluster 2. Distância: 0.1098221111733379
# Cluster 7 tem população baixa e será agrupado com o cluster 3. Distância: 0.30858612917340034

# %%
for (i, j) in agrupamentos:
        # Atualizar o índice de cluster para todos os pontos nos clusters i e j
        cluster_assignments[cluster_assignments == int(i)] = j

unique_clusters = np.unique(cluster_assignments)
for cluster in unique_clusters:
    cluster_data = data_normalized[np.array(cluster_assignments) == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], 
                label=f'Cluster {cluster + 1}', alpha=0.7)

# Plotando centróides (os pesos dos clusters)
centroids = art2.weights
plt.scatter(centroids[:,0], centroids[:,1], marker='x', 
            s=100, linewidths=2, color='k', label='Centróide')

plt.title("Clusters gerados pela ART 2")
plt.xlabel("Dimensão 1")
plt.ylabel("Dimensão 2")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Função para calcular a dispersão intra-cluster F_j
def calcular_dispersaointra(cluster_points, centroid):
    return np.sum(np.linalg.norm(cluster_points - centroid, axis=1))

# Função para calcular o diâmetro máximo do cluster
def calcular_diametro(cluster_points):
    distancias = [np.linalg.norm(point1 - point2) 
                  for i, point1 in enumerate(cluster_points) 
                  for j, point2 in enumerate(cluster_points) if i != j]
    return np.max(distancias)

# Função para calcular a variância intra-cluster
def calcular_variancia_intra(cluster_points, centroid):
    return np.var(np.linalg.norm(cluster_points - centroid, axis=1))

# Função para calcular o desvio padrão intra-cluster
def calcular_desvio_padrao_intra(variancia_intra):
    return np.sqrt(variancia_intra)

# Função para calcular a dispersão inter-cluster (F_out)
def calcular_dispersaointer(centroid_values, data_normalized, cluster_index, n_clusters):
    F_out_values = []
    for i in range(n_clusters):
        centroid_i = centroid_values[i]
        distancias = [np.linalg.norm(centroid_i - centroid_values[j]) for j in range(n_clusters) if i != j]
        F_out_values.append(np.mean(distancias))
    return np.mean(F_out_values)

data_normalized, data, n_0 = data_train_normalized, data_train, n_0_train
# Inicializando o ART2 com 2 dimensões e 5 clusters
art2 = ART2(input_dim=2, num_clusters=9, vigilance=0.3, learning_rate=0.6)
art2.train(data_normalized)
cluster_assignments = art2.predict(data_normalized)  # Clusters atribuídos

# Plotando os clusters
plt.figure(figsize=(8, 5))

unique_clusters = np.unique(cluster_assignments)
for cluster in unique_clusters:
    cluster_data = data_normalized[np.array(cluster_assignments) == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], 
                label=f'Cluster {cluster + 1}', alpha=0.7)

# Plotando centróides (os pesos dos clusters)
centroids = art2.weights
plt.scatter(centroids[:,0], centroids[:,1], marker='x', 
            s=100, linewidths=2, color='k', label='Centróide')

plt.title("Clusters gerados pela ART 2")
plt.xlabel("Dimensão 1")
plt.ylabel("Dimensão 2")
plt.legend()
plt.show()

# Inicializando as listas para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for cluster in unique_clusters:
    cluster_points = data_normalized[cluster_assignments == cluster]
    
    # Determinando o centróide do cluster (peso do cluster)
    centroid = art2.weights[cluster]
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(float(F_j))
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data_normalized, cluster_assignments, len(unique_clusters))

# Printando as métricas
print("Métricas para os clusters ART:")
print(f"Clusters: {unique_clusters}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {F_j_values}")
print(f"F_in (Dispersão intra-cluster): {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters ART:
# Clusters: [0 1 2 3 4 5 6 7 8]
# F_out (Dispersão inter-cluster): 0.585094167663231
# F_in (Dispersão intra-cluster) por cluster: [12.679409888224093, 1.4511374753866573, 1.3057041957395323, 2.4110435975541855, 2.055249486593049, 2.0977615666968763, 1.7926456865193914, 3.532338093848856, 2.334351718193027]
# F_in (Dispersão intra-cluster): 29.659641708755668
# Número de pontos por cluster: [41, 3, 4, 11, 7, 10, 5, 10, 9]
# Centróides dos clusters: [array([0.54495286, 0.83846668]), array([0.83740349, 0.54658521]), array([0.77329158, 0.51944578]), array([0.45731623, 0.61978457]), array([0.04342725, 0.98570094]), array([0.67538455, 0.11228591]), array([0.98268929, 0.30632522]), array([0.1828992 , 0.20077532]), array([0.05923665, 0.56496716])]
# Máxima distância (diâmetro) por cluster: [0.8954712877944084, 0.7553919099720151, 0.6939469037372819, 0.7902533152971148, 0.573444141226298, 0.864843185636325, 0.41282211369356275, 1.0360162215246826, 0.7217350496383778]
# Variância intra-cluster por cluster: [0.030605666086487186, 0.11470773723287149, 0.0020369339786189566, 0.010660316421040903, 0.040065120605285005, 0.017510262944835618, 0.020861518342203768, 0.046611160216984464, 0.010062224101685328]
# Desvio padrão intra-cluster por cluster: [0.17494475152598088, 0.33868530708147276, 0.04513240497269071, 0.1032488083274616, 0.20016273530626275, 0.1323263501530803, 0.14443517003210737, 0.21589617925517918, 0.10031063802850287]

# %%
import numpy as np
cluster_index = [i+1 for i in cluster_assignments]
# Função para calcular a distância entre dois pontos (centróides)
def calcular_distancia(centroid1, centroid2):
    return np.linalg.norm(centroid1 - centroid2)

# Função para decidir se clusters devem ser agrupados ou bipartidos
def verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points ,threshold=2, population_threshold = 5):
    n_clusters = len(centroid_values)
    agrupamentos = []  # Lista para armazenar decisões de agrupamento
    
    for i in range(n_clusters):
        for j in range(n_clusters):
            if i == j or (i,j) in agrupamentos:
                continue
            # Calcular a distância entre os centróides dos clusters i e j
            dist = calcular_distancia(centroid_values[i], centroid_values[j])

            sigma_sum = sigma_values[i] + sigma_values[j]
            
            # Comparar a distância entre centróides com a soma das dispersões
            if dist < sigma_sum * threshold:  # Se a distância for muito pequena, agrupar
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[j]))  # Armazenar os pares de clusters que devem ser agrupados
                print(f"Clusters {np.unique(cluster_index)[i]} e {np.unique(cluster_index)[j]} podem ser agrupados. Distância: {dist}, Soma das dispersões: {sigma_sum}")
            elif F_values[i] > F_values[j] and F_values[i] > 10 * F_values[j]:  # Se F_k for muito maior em um cluster
                print(f"Cluster {np.unique(cluster_index)[i]} tem alta dispersão (F_k), considerar bipartição.")
    for i in range(n_clusters):
        if n_cluster_points[i] < population_threshold:
            # Encontrar o cluster mais próximo para agrupar
            min_dist = float('inf')
            closest_cluster = None
            for j in range(n_clusters):
                if i != j and n_cluster_points[j] >= population_threshold:  # Não agrupar com clusters de baixa população
                    dist = calcular_distancia(centroid_values[i], centroid_values[j])
                    if dist < min_dist:
                        min_dist = dist
                        closest_cluster = j
            
            if closest_cluster is not None:
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[closest_cluster]))
                print(f"Cluster {np.unique(cluster_index)[i]} tem população baixa e será agrupado com o cluster {np.unique(cluster_index)[closest_cluster]}. Distância: {min_dist}")

        
    
    return agrupamentos

# Exemplo de centróides, dispersões e sigma (desvio padrão)
centroid_values = centroid_values

# Exemplo de dispersão F (somatória da distância intra-cluster)
F_values = F_j_values

# Exemplo de desvio padrão intra-cluster (σ)
sigma_values = desvio_padrao_intra_values

# Chamando a função para verificar agrupamento e bipartição
agrupamentos = verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points_values, 1.5, 9)

# Se necessário, implementar a lógica de bipartição para clusters com alta dispersão F_k
# Out:
# Clusters 1 e 2 podem ser agrupados. Distância: 0.41318539430735607, Soma das dispersões: 0.5136300586074536
# Clusters 1 e 4 podem ser agrupados. Distância: 0.235588724903138, Soma das dispersões: 0.27819355985344246
# Clusters 1 e 5 podem ser agrupados. Distância: 0.5226909859989498, Soma das dispersões: 0.3751074868322436
# Clusters 2 e 1 podem ser agrupados. Distância: 0.41318539430735607, Soma das dispersões: 0.5136300586074536
# Clusters 2 e 4 podem ser agrupados. Distância: 0.38707166320666403, Soma das dispersões: 0.44193411540893435
# Clusters 2 e 7 podem ser agrupados. Distância: 0.2807718348174575, Soma das dispersões: 0.48312047711358014
# Clusters 2 e 8 podem ser agrupados. Distância: 0.7402434375699615, Soma das dispersões: 0.5545814863366519
# Clusters 4 e 1 podem ser agrupados. Distância: 0.235588724903138, Soma das dispersões: 0.27819355985344246
# Clusters 4 e 2 podem ser agrupados. Distância: 0.38707166320666403, Soma das dispersões: 0.44193411540893435
# Clusters 5 e 1 podem ser agrupados. Distância: 0.5226909859989498, Soma das dispersões: 0.3751074868322436
# Clusters 5 e 9 podem ser agrupados. Distância: 0.42103070311327434, Soma das dispersões: 0.30047337333476565
# Clusters 6 e 7 podem ser agrupados. Distância: 0.3634383801694158, Soma das dispersões: 0.2767615201851877
# Clusters 6 e 8 podem ser agrupados. Distância: 0.5003720556237148, Soma das dispersões: 0.3482225294082595
# Clusters 7 e 2 podem ser agrupados. Distância: 0.2807718348174575, Soma das dispersões: 0.48312047711358014
# Clusters 7 e 6 podem ser agrupados. Distância: 0.3634383801694158, Soma das dispersões: 0.2767615201851877
# Clusters 8 e 2 podem ser agrupados. Distância: 0.7402434375699615, Soma das dispersões: 0.5545814863366519
# Clusters 8 e 6 podem ser agrupados. Distância: 0.5003720556237148, Soma das dispersões: 0.3482225294082595
# Clusters 8 e 9 podem ser agrupados. Distância: 0.3846142496548762, Soma das dispersões: 0.31620681728368205
# Clusters 9 e 5 podem ser agrupados. Distância: 0.42103070311327434, Soma das dispersões: 0.30047337333476565
# Clusters 9 e 8 podem ser agrupados. Distância: 0.3846142496548762, Soma das dispersões: 0.31620681728368205
# Cluster 2 tem população baixa e será agrupado com o cluster 4. Distância: 0.38707166320666403
# Cluster 3 tem população baixa e será agrupado com o cluster 4. Distância: 0.3315242015771162
# Cluster 5 tem população baixa e será agrupado com o cluster 9. Distância: 0.42103070311327434
# Cluster 7 tem população baixa e será agrupado com o cluster 6. Distância: 0.3634383801694158

# %%
for (i, j) in agrupamentos:
        # Atualizar o índice de cluster para todos os pontos nos clusters i e j
        cluster_assignments[cluster_assignments == int(i)] = j

unique_clusters = np.unique(cluster_assignments)
for cluster in unique_clusters:
    cluster_data = data_normalized[np.array(cluster_assignments) == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], 
                label=f'Cluster {cluster + 1}', alpha=0.7)

# Plotando centróides (os pesos dos clusters)
centroids = art2.weights
plt.scatter(centroids[:,0], centroids[:,1], marker='x', 
            s=100, linewidths=2, color='k', label='Centróide')

plt.title("Clusters gerados pela ART 2")
plt.xlabel("Dimensão 1")
plt.ylabel("Dimensão 2")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Função para calcular a dispersão intra-cluster F_j
def calcular_dispersaointra(cluster_points, centroid):
    return np.sum(np.linalg.norm(cluster_points - centroid, axis=1))

# Função para calcular o diâmetro máximo do cluster
def calcular_diametro(cluster_points):
    distancias = [np.linalg.norm(point1 - point2) 
                  for i, point1 in enumerate(cluster_points) 
                  for j, point2 in enumerate(cluster_points) if i != j]
    return np.max(distancias)

# Função para calcular a variância intra-cluster
def calcular_variancia_intra(cluster_points, centroid):
    return np.var(np.linalg.norm(cluster_points - centroid, axis=1))

# Função para calcular o desvio padrão intra-cluster
def calcular_desvio_padrao_intra(variancia_intra):
    return np.sqrt(variancia_intra)

# Função para calcular a dispersão inter-cluster (F_out)
def calcular_dispersaointer(centroid_values, data_normalized, cluster_index, n_clusters):
    F_out_values = []
    for i in range(n_clusters):
        centroid_i = centroid_values[i]
        distancias = [np.linalg.norm(centroid_i - centroid_values[j]) for j in range(n_clusters) if i != j]
        F_out_values.append(np.mean(distancias))
    return np.mean(F_out_values)

data_normalized, data, n_0 = data_val_normalized, data_val, n_0_val
# Inicializando o ART2 com 2 dimensões e 5 clusters
art2 = ART2(input_dim=2, num_clusters=9, vigilance=0.3, learning_rate=0.6)
art2.train(data_normalized)
cluster_assignments = art2.predict(data_normalized)  # Clusters atribuídos

# Plotando os clusters
plt.figure(figsize=(8, 5))

unique_clusters = np.unique(cluster_assignments)
for cluster in unique_clusters:
    cluster_data = data_normalized[np.array(cluster_assignments) == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], 
                label=f'Cluster {cluster + 1}', alpha=0.7)

# Plotando centróides (os pesos dos clusters)
centroids = art2.weights
plt.scatter(centroids[:,0], centroids[:,1], marker='x', 
            s=100, linewidths=2, color='k', label='Centróide')

plt.title("Clusters gerados pela ART 2")
plt.xlabel("Dimensão 1")
plt.ylabel("Dimensão 2")
plt.legend()
plt.show()

# Inicializando as listas para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for cluster in unique_clusters:
    cluster_points = data_normalized[cluster_assignments == cluster]
    
    # Determinando o centróide do cluster (peso do cluster)
    centroid = art2.weights[cluster]
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(float(F_j))
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data_normalized, cluster_assignments, len(unique_clusters))

# Printando as métricas
print("Métricas para os clusters ART:")
print(f"Clusters: {unique_clusters}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {F_j_values}")
print(f"F_in (Dispersão intra-cluster): {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters ART:
# Clusters: [0 1 2 3 4 5 6 7 8]
# F_out (Dispersão inter-cluster): 0.5497502313923578
# F_in (Dispersão intra-cluster) por cluster: [10.743565670235819, 1.1427573386605534, 13.755113969078192, 0.4541801144875965, 4.770913370798414, 2.351030981889925, 1.3703437883967895, 1.9240598637876754, 0.5859450431781015]
# F_in (Dispersão intra-cluster): 37.097910140513065
# Número de pontos por cluster: [33, 3, 24, 5, 17, 5, 3, 8, 2]
# Centróides dos clusters: [array([0.49104887, 0.87113202]), array([0.89588806, 0.00143544]), array([0.7756114 , 0.93974322]), array([0.54139039, 0.18927699]), array([0.08697961, 0.60666843]), array([0.39677183, 0.3504199 ]), array([0.84411837, 0.574686  ]), array([0.37274432, 0.08383068]), array([0.5529127 , 0.30295134])]
# Máxima distância (diâmetro) por cluster: [1.0594295875514455, 0.049180327868852514, 0.9617203899240503, 0.21423736873208413, 0.9690620406673258, 0.5815070730001418, 0.063035198423246, 0.7482202523921422, 0.5382583277839578]
# Variância intra-cluster por cluster: [0.03400069348844192, 0.0003996295503508707, 0.04615484616445032, 0.005061591421242244, 0.01753561263263509, 0.04243120241395111, 0.0003859170039083487, 0.013993745384447653, 0.0603188900433364]
# Desvio padrão intra-cluster por cluster: [0.18439276962083387, 0.019990736613513537, 0.21483678959724362, 0.07114486222660245, 0.1324221002425014, 0.20598835504452942, 0.019644770395918318, 0.11829516213458457, 0.24559904324597112]

# %%
import numpy as np
cluster_index = [i+1 for i in cluster_assignments]
# Função para calcular a distância entre dois pontos (centróides)
def calcular_distancia(centroid1, centroid2):
    return np.linalg.norm(centroid1 - centroid2)

# Função para decidir se clusters devem ser agrupados ou bipartidos
def verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points ,threshold=2, population_threshold = 5):
    n_clusters = len(centroid_values)
    agrupamentos = []  # Lista para armazenar decisões de agrupamento
    
    for i in range(n_clusters):
        for j in range(n_clusters):
            if i == j or (i,j) in agrupamentos:
                continue
            # Calcular a distância entre os centróides dos clusters i e j
            dist = calcular_distancia(centroid_values[i], centroid_values[j])

            sigma_sum = sigma_values[i] + sigma_values[j]
            
            # Comparar a distância entre centróides com a soma das dispersões
            if dist < sigma_sum * threshold:  # Se a distância for muito pequena, agrupar
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[j]))  # Armazenar os pares de clusters que devem ser agrupados
                print(f"Clusters {np.unique(cluster_index)[i]} e {np.unique(cluster_index)[j]} podem ser agrupados. Distância: {dist}, Soma das dispersões: {sigma_sum}")
            elif F_values[i] > F_values[j] and F_values[i] > 10 * F_values[j]:  # Se F_k for muito maior em um cluster
                print(f"Cluster {np.unique(cluster_index)[i]} tem alta dispersão (F_k), considerar bipartição.")
    for i in range(n_clusters):
        if n_cluster_points[i] < population_threshold:
            # Encontrar o cluster mais próximo para agrupar
            min_dist = float('inf')
            closest_cluster = None
            for j in range(n_clusters):
                if i != j and n_cluster_points[j] >= population_threshold:  # Não agrupar com clusters de baixa população
                    dist = calcular_distancia(centroid_values[i], centroid_values[j])
                    if dist < min_dist:
                        min_dist = dist
                        closest_cluster = j
            
            if closest_cluster is not None:
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[closest_cluster]))
                print(f"Cluster {np.unique(cluster_index)[i]} tem população baixa e será agrupado com o cluster {np.unique(cluster_index)[closest_cluster]}. Distância: {min_dist}")

        
    
    return agrupamentos

# Exemplo de centróides, dispersões e sigma (desvio padrão)
centroid_values = centroid_values

# Exemplo de dispersão F (somatória da distância intra-cluster)
F_values = F_j_values

# Exemplo de desvio padrão intra-cluster (σ)
sigma_values = desvio_padrao_intra_values

# Chamando a função para verificar agrupamento e bipartição
agrupamentos = verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points_values, 1.5, 9)

# Se necessário, implementar a lógica de bipartição para clusters com alta dispersão F_k
# Out:
# Clusters 1 e 3 podem ser agrupados. Distância: 0.2927171443987613, Soma das dispersões: 0.39922955921807746
# Cluster 1 tem alta dispersão (F_k), considerar bipartição.
# Clusters 1 e 6 podem ser agrupados. Distância: 0.5291779284636557, Soma das dispersões: 0.3903811246653633
# Clusters 1 e 9 podem ser agrupados. Distância: 0.5715386414044954, Soma das dispersões: 0.429991812866805
# Clusters 3 e 1 podem ser agrupados. Distância: 0.2927171443987613, Soma das dispersões: 0.39922955921807746
# Cluster 3 tem alta dispersão (F_k), considerar bipartição.
# Cluster 3 tem alta dispersão (F_k), considerar bipartição.
# Cluster 3 tem alta dispersão (F_k), considerar bipartição.
# Clusters 3 e 9 podem ser agrupados. Distância: 0.6746099629599455, Soma das dispersões: 0.46043583284321477
# Clusters 4 e 6 podem ser agrupados. Distância: 0.21652150738967718, Soma das dispersões: 0.2771332172711319
# Clusters 4 e 8 podem ser agrupados. Distância: 0.1988980198014841, Soma das dispersões: 0.189440024361187
# Clusters 4 e 9 podem ser agrupados. Distância: 0.11425682556723547, Soma das dispersões: 0.3167439054725736
# Cluster 5 tem alta dispersão (F_k), considerar bipartição.
# Clusters 5 e 6 podem ser agrupados. Distância: 0.4020379752443104, Soma das dispersões: 0.33841045528703084
# Clusters 6 e 1 podem ser agrupados. Distância: 0.5291779284636557, Soma das dispersões: 0.3903811246653633
# Clusters 6 e 4 podem ser agrupados. Distância: 0.21652150738967718, Soma das dispersões: 0.2771332172711319
# Clusters 6 e 5 podem ser agrupados. Distância: 0.4020379752443104, Soma das dispersões: 0.33841045528703084
# Clusters 6 e 8 podem ser agrupados. Distância: 0.26766982189524285, Soma das dispersões: 0.32428351717911397
# Clusters 6 e 9 podem ser agrupados. Distância: 0.16319691302279446, Soma das dispersões: 0.45158739829050054
# Clusters 8 e 4 podem ser agrupados. Distância: 0.1988980198014841, Soma das dispersões: 0.189440024361187
# Clusters 8 e 6 podem ser agrupados. Distância: 0.26766982189524285, Soma das dispersões: 0.32428351717911397
# Clusters 8 e 9 podem ser agrupados. Distância: 0.28368029668410527, Soma das dispersões: 0.3638942053805557
# Clusters 9 e 1 podem ser agrupados. Distância: 0.5715386414044954, Soma das dispersões: 0.429991812866805
# Clusters 9 e 3 podem ser agrupados. Distância: 0.6746099629599455, Soma das dispersões: 0.46043583284321477
# Clusters 9 e 4 podem ser agrupados. Distância: 0.11425682556723547, Soma das dispersões: 0.3167439054725736
# Clusters 9 e 6 podem ser agrupados. Distância: 0.16319691302279446, Soma das dispersões: 0.45158739829050054
# Clusters 9 e 8 podem ser agrupados. Distância: 0.28368029668410527, Soma das dispersões: 0.3638942053805557
# Cluster 2 tem população baixa e será agrupado com o cluster 3. Distância: 0.9459851849054246
# Cluster 4 tem população baixa e será agrupado com o cluster 5. Distância: 0.617012781611193
# Cluster 6 tem população baixa e será agrupado com o cluster 5. Distância: 0.4020379752443104
# Cluster 7 tem população baixa e será agrupado com o cluster 3. Distância: 0.3714296443800876
# Cluster 8 tem população baixa e será agrupado com o cluster 5. Distância: 0.5958362091478556
# Cluster 9 tem população baixa e será agrupado com o cluster 5. Distância: 0.5561813640945216

# %%
for (i, j) in agrupamentos:
        # Atualizar o índice de cluster para todos os pontos nos clusters i e j
        cluster_assignments[cluster_assignments == int(i)] = j

unique_clusters = np.unique(cluster_assignments)
for cluster in unique_clusters:
    cluster_data = data_normalized[np.array(cluster_assignments) == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], 
                label=f'Cluster {cluster + 1}', alpha=0.7)

# Plotando centróides (os pesos dos clusters)
centroids = art2.weights
plt.scatter(centroids[:,0], centroids[:,1], marker='x', 
            s=100, linewidths=2, color='k', label='Centróide')

plt.title("Clusters gerados pela ART 2")
plt.xlabel("Dimensão 1")
plt.ylabel("Dimensão 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Resultado Final
# Aqui podemos ver que existem 5 clusters de clientes com base na renda anual e na pontuação de gastos:
#
# Cluster 0: Alta renda, baixo gasto
#
# Cluster 1: Alta renda, alto gasto
#
# Cluster 2: Baixa renda, alto gasto
#
# Cluster 3: Renda média, gasto médio
#
# Cluster 4: Baixa renda, baixo gasto
