# %%
# Este ambiente Python 3 vem com muitas bibliotecas de análise úteis instaladas
# Ele é definido pela imagem Docker kaggle/python: https://github.com/kaggle/docker-python
# Por exemplo, aqui estão vários pacotes úteis para carregar

import numpy as np # álgebra linear
import pandas as pd # processamento de dados, E/S de arquivos CSV (por exemplo, pd.read_csv)


import numpy as np
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from scipy.spatial.distance import cdist
from minisom import MiniSom  

import matplotlib.pyplot as plt
# %matplotlib inline

# Os arquivos de dados de entrada estão disponíveis no diretório somente leitura "../input/"
# Por exemplo, executar isso (clicando em executar ou pressionando Shift+Enter) listará todos os arquivos no diretório de entrada

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Você pode escrever até 20GB no diretório atual (/kaggle/working/) que é preservado como saída quando você cria uma versão usando "Salvar & Executar Tudo"
# Você também pode escrever arquivos temporários em /kaggle/temp/, mas eles não serão salvos fora da sessão atual

# %% [markdown]
# ## Introdução
#
# Neste notebook, demonstraremos como usar o minisom para fazer clustering de topologia linear
#
# Por favor, vote positivamente neste notebook se achar útil :)
#
# Jonathan Kristanto &copy; Maio 2021

# %% [markdown]
# ## Importar Dados

# %%
DATA_DIR = './dataset/Mall_Customers.csv'
df = pd.read_csv(DATA_DIR)
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Seleção de Características
#
# Veremos quais combinações de características podem ser agrupadas

# %% [markdown]
# ### Distribuição de Dados de Idade e Pontuação de Gastos
#
# Resultado: Nenhum cluster aparente detectado

# %%
age = df['Age'].tolist()
spending_score = df['Spending Score (1-100)'].tolist()
annual_income = df['Annual Income (k$)'].tolist()
fig = plt.figure(figsize=(6,6))
plt.scatter(age, spending_score)
plt.suptitle("Gráfico de Dispersão de Idade e Pontuação de Gastos")
plt.xlabel("Idade")
plt.ylabel("Pontuação de Gastos")
plt.show()

# %% [markdown]
# ### Distribuição de Dados de Idade e Renda Anual
#
# Resultado: Nenhum cluster aparente detectado

# %%
age = df['Age'].tolist()
annual_income = df['Annual Income (k$)'].tolist()
fig = plt.figure(figsize=(6,6))
plt.scatter(age, annual_income)
plt.suptitle("Gráfico de Dispersão de Idade e Renda Anual")
plt.xlabel("Idade")
plt.ylabel("Renda Anual (k$)")
plt.show()

# %% [markdown]
# ### Distribuição de Dados de Renda Anual e Pontuação de Gastos
#
# **Resultado: Existem 5 clusters detectados**

# %%
annual_income = df['Annual Income (k$)'].tolist()
spending_score = df['Spending Score (1-100)'].tolist()
fig = plt.figure(figsize=(6,6))
plt.scatter(annual_income, spending_score)
plt.suptitle("Gráfico de Dispersão de Renda Anual & Pontuação de Gastos")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.show()

# %% [markdown]
# ## Limpar & Transformar Dados

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Selecionar Renda Anual e Pontuação de Gastos como nossas características
features = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# Transformar características em lista
data = features.values
data.shape

from sklearn.preprocessing import MinMaxScaler

# Criar o MinMaxScaler
scaler = MinMaxScaler()

# Ajustar e transformar os dados
data_normalized = scaler.fit_transform(data)

# %% [markdown]
# # Parâmetros gerais do dataset

# %%
global_centroid = np.mean(data_normalized, axis=0) # Calcular o centróide global
F_0 = np.sum(np.linalg.norm(data_normalized - global_centroid, axis=1)**2) # Calcular F_0 (dispersão total)
n_0 = data_normalized.shape[0] # Número total de pontos
sigma_0 = np.sqrt(F_0 / n_0) # Calcular o desvio padrão total

print(f"Número total de elementos (n_0): {n_0}")
print(f"Baricentro Global (m_0): ", global_centroid)
print(f"Dispersão total (F_0): {F_0:.2f}")
print(f"Desvio padrão total (\\sigma_0): {sigma_0:.2f}")
# Out:
# Número total de elementos (n_0): 200
# Baricentro Global (m_0):  [0.37344262 0.50204082]
# Dispersão total (F_0): 23.04
# Desvio padrão total (\sigma_0): 0.34

# %% [markdown]
# # Treinamento dos Modelos

# %% [markdown]
# ## K-means

# %%
""""
import numpy as np
from sklearn.cluster import KMeans

# Função para calcular a dispersão intra-cluster F_j
def calcular_dispersaointra(cluster_points, centroid):
    return np.sum(np.linalg.norm(cluster_points - centroid, axis=1)**2)

# Função para calcular o diâmetro máximo do cluster
def calcular_diametro(cluster_points):
    max_distance = 0
    for i in range(len(cluster_points)):
        for k in range(i + 1, len(cluster_points)):
            dist = np.linalg.norm(cluster_points[i] - cluster_points[k])
            max_distance = max(max_distance, dist)
    return max_distance

# Função para calcular a variância intra-cluster
def calcular_variancia_intra(cluster_points, centroid):
    return np.mean(np.linalg.norm(cluster_points - centroid, axis=1)**2)

# Função para calcular o desvio padrão intra-cluster
def calcular_desvio_padrao_intra(variancia_intra):
    return np.sqrt(variancia_intra)

# Função para calcular a dispersão inter-cluster F_out
def calcular_dispersaointer(centroids, data, labels, n_clusters):
    F_out = 0
    global_centroid = np.mean(centroids, axis=0)  # Centróide global (média dos centróides dos clusters)
    for j in range(n_clusters):
        cluster_points = data[labels == j]  # Dados no cluster j
        n_j = len(cluster_points)           # Número de pontos no cluster j
        centroid_j = centroids[j]           # Centróide do cluster j
        F_out += n_j * np.linalg.norm(centroid_j - global_centroid)**2
    return F_out

# Função principal para calcular as métricas do KMeans
def calcular_metricas_cluster_kmeans(data, max_clusters=10):
    # Inicialização das listas para armazenar os resultados
    F_out_values = []
    F_in_values = []
    n_cluster_points_values = []
    centroid_values = []
    max_distance_values = []
    variancia_intra_values = []
    desvio_padrao_intra_values = []

    # Selecionar as características para clustering
    X = df[['Annual Income (k$)', 'Spending Score (1-100)']]
    # Dividir os dados em treino e validação
    X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)


    # Loop para diferentes números de clusters
    for n_clusters in range(1, max_clusters + 1):
        kmeans_train = KMeans(n_clusters=n_clusters, random_state=0).fit(X_train)
        kmeans_val = KMeans(n_clusters=n_clusters, random_state=0).fit(X_val)
        # kmeans = KMeans(n_clusters=n_clusters, random_state=0)
        # kmeans.fit(data)
        
        # Obter os rótulos e centróides
        labels = kmeans_train.labels_
        centroids = kmeans_train.cluster_centers_

        # Calcular F_j para cada cluster
        F_j_values = []
        n_cluster_points_l_values = []
        max_distance_l_values = []
        variancia_intra_l_values = []
        desvio_padrao_intra_l_values = []
        
        # Loop sobre cada cluster
        for j in range(n_clusters):
            cluster_points = X_train[labels == j]  # Dados no cluster j
            centroid = centroids[j]             # Centróide do cluster j

            n_cluster_points_l_values.append(len(cluster_points))
            centroid_values.append(centroid)
            
            # Calcular dispersão intra-cluster F_j
            F_j = calcular_dispersaointra(cluster_points, centroid)
            F_j_values.append(float(F_j))
            
            # Calcular o diâmetro do cluster (maior distância entre os pontos dentro do cluster)
            max_distance = calcular_diametro(cluster_points)
            max_distance_l_values.append(float(max_distance))
            
            # Calcular a variância intra-classe
            variancia_intra = calcular_variancia_intra(cluster_points, centroid)
            variancia_intra_l_values.append(float(variancia_intra))
            
            # Calcular o desvio padrão intra-classe
            desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
            desvio_padrao_intra_l_values.append(float(desvio_padrao_intra))
        
        F_in_values.append(F_j_values.copy())
        
        # Calcular F_out (dispersão inter-cluster)
        F_out = calcular_dispersaointer(centroids, data, labels, n_clusters)
        
        F_out_values.append(F_out)
        n_cluster_points_values.append(n_cluster_points_l_values)
        max_distance_values.append(max_distance_l_values.copy())
        variancia_intra_values.append(variancia_intra_l_values.copy())
        desvio_padrao_intra_values.append(desvio_padrao_intra_l_values.copy())

    return F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values


def plot_metricas_clusters(F_out_values, F_in_values, max_clusters=10):
    # Número de clusters de 1 a max_clusters
    clusters_range = range(1, max_clusters + 1)

    # Calcular a dispersão total intra-cluster (F_in) para cada número de clusters
    total_F_in_values = [sum(F_in) for F_in in F_in_values]

    # Plotar as métricas
    plt.figure(figsize=(10, 6))

    # Gráfico da dispersão intra-cluster (F_in)
    plt.plot(clusters_range, total_F_in_values, label="Dispersão Intra-cluster (F_in)", marker='o', color='blue')

    # Gráfico da dissimilaridade inter-cluster (F_out)
    plt.plot(clusters_range, F_out_values, label="Dissimilaridade Inter-cluster (F_out)", marker='x', color='red')

    # Adicionando rótulos e título
    plt.xlabel("Número de clusters")
    plt.ylabel("Valor das métricas")
    plt.title("Dispersão intra-cluster (F_in) e Dissimilaridade inter-cluster (F_out) por número de clusters")
    plt.legend()
    plt.grid(True)

    # Exibir o gráfico
    plt.show()
    
    """
# Out:
# '"\nimport numpy as np\nfrom sklearn.cluster import KMeans\n\n# Função para calcular a dispersão intra-cluster F_j\ndef calcular_dispersaointra(cluster_points, centroid):\n    return np.sum(np.linalg.norm(cluster_points - centroid, axis=1)**2)\n\n# Função para calcular o diâmetro máximo do cluster\ndef calcular_diametro(cluster_points):\n    max_distance = 0\n    for i in range(len(cluster_points)):\n        for k in range(i + 1, len(cluster_points)):\n            dist = np.linalg.norm(cluster_points[i] - cluster_points[k])\n            max_distance = max(max_distance, dist)\n    return max_distance\n\n# Função para calcular a variância intra-cluster\ndef calcular_variancia_intra(cluster_points, centroid):\n    return np.mean(np.linalg.norm(cluster_points - centroid, axis=1)**2)\n\n# Função para calcular o desvio padrão intra-cluster\ndef calcular_desvio_padrao_intra(variancia_intra):\n    return np.sqrt(variancia_intra)\n\n# Função para calcular a dispersão inter-cluster F_out\ndef calcular_dispersaointer(centroids, data, labels, n_clusters):\n    F_out = 0\n    global_centroid = np.mean(centroids, axis=0)  # Centróide global (média dos centróides dos clusters)\n    for j in range(n_clusters):\n        cluster_points = data[labels == j]  # Dados no cluster j\n        n_j = len(cluster_points)           # Número de pontos no cluster j\n        centroid_j = centroids[j]           # Centróide do cluster j\n        F_out += n_j * np.linalg.norm(centroid_j - global_centroid)**2\n    return F_out\n\n# Função principal para calcular as métricas do KMeans\ndef calcular_metricas_cluster_kmeans(data, max_clusters=10):\n    # Inicialização das listas para armazenar os resultados\n    F_out_values = []\n    F_in_values = []\n    n_cluster_points_values = []\n    centroid_values = []\n    max_distance_values = []\n    variancia_intra_values = []\n    desvio_padrao_intra_values = []\n\n    # Selecionar as características para clustering\n    X = df[[\'Annual Income (k$)\', \'Spending Score (1-100)\']]\n    # Dividir os dados em treino e validação\n    X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)\n\n\n    # Loop para diferentes números de clusters\n    for n_clusters in range(1, max_clusters + 1):\n        kmeans_train = KMeans(n_clusters=n_clusters, random_state=0).fit(X_train)\n        kmeans_val = KMeans(n_clusters=n_clusters, random_state=0).fit(X_val)\n        # kmeans = KMeans(n_clusters=n_clusters, random_state=0)\n        # kmeans.fit(data)\n        \n        # Obter os rótulos e centróides\n        labels = kmeans_train.labels_\n        centroids = kmeans_train.cluster_centers_\n\n        # Calcular F_j para cada cluster\n        F_j_values = []\n        n_cluster_points_l_values = []\n        max_distance_l_values = []\n        variancia_intra_l_values = []\n        desvio_padrao_intra_l_values = []\n        \n        # Loop sobre cada cluster\n        for j in range(n_clusters):\n            cluster_points = X_train[labels == j]  # Dados no cluster j\n            centroid = centroids[j]             # Centróide do cluster j\n\n            n_cluster_points_l_values.append(len(cluster_points))\n            centroid_values.append(centroid)\n            \n            # Calcular dispersão intra-cluster F_j\n            F_j = calcular_dispersaointra(cluster_points, centroid)\n            F_j_values.append(float(F_j))\n            \n            # Calcular o diâmetro do cluster (maior distância entre os pontos dentro do cluster)\n            max_distance = calcular_diametro(cluster_points)\n            max_distance_l_values.append(float(max_distance))\n            \n            # Calcular a variância intra-classe\n            variancia_intra = calcular_variancia_intra(cluster_points, centroid)\n            variancia_intra_l_values.append(float(variancia_intra))\n            \n            # Calcular o desvio padrão intra-classe\n            desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)\n        ...

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from scipy.spatial.distance import cdist

# Função para calcular a dispersão intra-cluster
def calcular_dispersaointra(cluster_points, centroid):
    return np.sum(np.linalg.norm(cluster_points - centroid, axis=1)**2)

# Função para calcular o diâmetro máximo do cluster
def calcular_diametro(cluster_points):
    max_distance = 0
    for i in range(len(cluster_points)):
        for k in range(i + 1, len(cluster_points)):
            dist = np.linalg.norm(cluster_points[i] - cluster_points[k])
            max_distance = max(max_distance, dist)
    return max_distance

# Função para calcular a variância intra-cluster
def calcular_variancia_intra(cluster_points, centroid):
    return np.mean(np.linalg.norm(cluster_points - centroid, axis=1)**2)

# Função para calcular o desvio padrão intra-cluster
def calcular_desvio_padrao_intra(variancia_intra):
    return np.sqrt(variancia_intra)

# Função para calcular a dispersão inter-cluster
def calcular_dispersaointer(centroids, data, labels, n_clusters):
    F_out = 0
    global_centroid = np.mean(centroids, axis=0)  # Centróide global (média dos centróides dos clusters)
    for j in range(n_clusters):
        cluster_points = data[labels == j]  # Dados no cluster j
        n_j = len(cluster_points)           # Número de pontos no cluster j
        centroid_j = centroids[j]           # Centróide do cluster j
        F_out += n_j * np.linalg.norm(centroid_j - global_centroid)**2
    return F_out

# Função principal para calcular as métricas do KMeans
def calcular_metricas_cluster_kmeans(data, max_clusters=10):
    # Inicialização das listas para armazenar os resultados
    F_out_values = []
    F_in_values = []
    n_cluster_points_values = []
    centroid_values = []
    max_distance_values = []
    variancia_intra_values = []
    desvio_padrao_intra_values = []

    # Dividir os dados em treino e validação
    X_train, X_val = train_test_split(data, test_size=0.2, random_state=42)

    # Loop para diferentes números de clusters
    for n_clusters in range(1, max_clusters + 1):
        kmeans_train = KMeans(n_clusters=n_clusters, random_state=0).fit(X_train)
        kmeans_val = KMeans(n_clusters=n_clusters, random_state=0).fit(X_val)
        
        # Obter os rótulos e centróides
        labels_train = kmeans_train.labels_
        centroids_train = kmeans_train.cluster_centers_
        labels_val = kmeans_val.labels_
        centroids_val = kmeans_val.cluster_centers_

        # Calcular F_j para cada cluster
        F_j_values = []
        n_cluster_points_l_values = []
        max_distance_l_values = []
        variancia_intra_l_values = []
        desvio_padrao_intra_l_values = []
        
        # Loop sobre cada cluster
        for j in range(n_clusters):
            cluster_points_train = X_train[labels_train == j]  # Dados no cluster j (treino)
            cluster_points_val = X_val[labels_val == j]        # Dados no cluster j (validação)
            centroid_train = centroids_train[j]                # Centróide do cluster j (treino)
            centroid_val = centroids_val[j]                    # Centróide do cluster j (validação)

            n_cluster_points_l_values.append(len(cluster_points_train))
            centroid_values.append((centroid_train, centroid_val))
            
            # Calcular dispersão intra-cluster F_j
            F_j = calcular_dispersaointra(cluster_points_train, centroid_train)
            F_j_values.append(float(F_j))
            
            # Calcular o diâmetro do cluster (maior distância entre os pontos dentro do cluster)
            max_distance = calcular_diametro(cluster_points_train)
            max_distance_l_values.append(float(max_distance))
            
            # Calcular a variância intra-classe
            variancia_intra = calcular_variancia_intra(cluster_points_train, centroid_train)
            variancia_intra_l_values.append(float(variancia_intra))
            
            # Calcular o desvio padrão intra-classe
            desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
            desvio_padrao_intra_l_values.append(float(desvio_padrao_intra))
        
        F_in_values.append(F_j_values.copy())
        
        # Calcular F_out (dispersão inter-cluster)
        F_out = calcular_dispersaointer(centroids_train, X_train, labels_train, n_clusters)
        
        F_out_values.append(F_out)
        n_cluster_points_values.append(n_cluster_points_l_values)
        max_distance_values.append(max_distance_l_values.copy())
        variancia_intra_values.append(variancia_intra_l_values.copy())
        desvio_padrao_intra_values.append(desvio_padrao_intra_l_values.copy())

    return F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values

F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values = calcular_metricas_cluster_kmeans(data, 10)

# Comparar a posição dos centroides nos conjuntos de treino e validação
distancias_centroides = []
max_clusters = 10  # Definir o máximo de clusters a serem comparados
for idx, (centroid_train, centroid_val) in enumerate(centroid_values):
    if idx >= max_clusters:
        break
    distance = np.linalg.norm(centroid_train - centroid_val)
    distancias_centroides.append(distance)
    print(f"Distância entre os centroides do cluster {idx+1}: {distance}")


# Função para plotar as distâncias entre os centroides
def plot_distancias_centroides(distancias_centroides, max_clusters=10):
    # Limitar o número de clusters a serem plotados
    num_clusters = min(len(distancias_centroides), max_clusters)
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, num_clusters + 1), distancias_centroides[:num_clusters], marker='o')
    plt.xlabel('Número de Clusters')
    plt.ylabel('Distância entre Centroides')
    plt.title('Distância entre Centroides dos Conjuntos de Treino e Validação')
    plt.show()

# Plotar as distâncias entre os centroides
plot_distancias_centroides(distancias_centroides, max_clusters=10)


# # Comparar a posição dos centroides nos conjuntos de treino e validação
# for idx, (centroid_train, centroid_val) in enumerate(centroid_values):
#     distance = np.linalg.norm(centroid_train - centroid_val)
#     print(f"Distância entre os centroides do cluster {idx+1}: {distance}")

# Exibir as métricas calculadas
for idx, (F_out, F_in, n_cluster_points, centroid, max_distance, variancia_intra, desvio_padrao_intra) in enumerate(zip(F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values)):
    print(f"Clusters: {idx+1}")
    print(f"   Número de elementos (n_j): ", n_cluster_points)
    print(f"   Baricentro (m_j): ", centroid)
    print(f"   Diâmetro do cluster: ", max_distance)
    print(f"   Variância intra-cluster: ", variancia_intra)
    print(f"   Desvio padrão intra-cluster: ", desvio_padrao_intra)
    print(f"   Dispersão intra-cluster (F_ji): ", F_in)
    print(f"   Dispersão total intra-cluster (F_in): {sum(F_in)}")
    print(f"   Dissimilaridade inter-cluster (F_out): {(F_out)}")

# Função para plotar as métricas dos clusters (exemplo)
def plot_metricas_clusters(F_out_values, F_in_values, max_clusters=10):
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, max_clusters + 1), F_out_values, label='Dispersão Inter-Cluster (F_out)')
    plt.plot(range(1, max_clusters + 1), [sum(F_in) for F_in in F_in_values], label='Dispersão Intra-Cluster (F_in)')
    plt.xlabel('Número de Clusters')
    plt.ylabel('Dispersão')
    plt.title('Dispersão Intra e Inter-Cluster')
    plt.legend()
    plt.show()

plot_metricas_clusters(F_out_values, F_in_values, max_clusters=10)
# Out:
# Distância entre os centroides do cluster 1: 7.87839460566047
# Distância entre os centroides do cluster 2: 43.242969331134546
# Distância entre os centroides do cluster 3: 39.53238047668784
# Distância entre os centroides do cluster 4: 73.43882328230994
# Distância entre os centroides do cluster 5: 49.15765047273925
# Distância entre os centroides do cluster 6: 50.19293659620657
# Distância entre os centroides do cluster 7: 76.08182287265663
# Distância entre os centroides do cluster 8: 41.1144935987134
# Distância entre os centroides do cluster 9: 51.14310327253986
# Distância entre os centroides do cluster 10: 52.27888669874134
# Clusters: 1
#    Número de elementos (n_j):  [160]
#    Baricentro (m_j):  (array([60.60625, 51.775  ]), array([60.375, 43.9  ]))
#    Diâmetro do cluster:  [143.42245291445826]
#    Variância intra-cluster:  [1439.4880859375]
#    Desvio padrão intra-cluster:  [37.94058626243801]
#    Dispersão intra-cluster (F_ji):  [230318.09375]
#    Dispersão total intra-cluster (F_in): 230318.09375
#    Dissimilaridade inter-cluster (F_out): 0.0
# Clusters: 2
#    Número de elementos (n_j):  [42, 118]
#    Baricentro (m_j):  (array([92.47619048, 71.47619048]), array([51.88888889, 56.55555556]))
#    Diâmetro do cluster:  [101.41498903022176, 114.38968484964018]
#    Variância intra-cluster:  [998.4988662131519, 918.9339988509048]
#    Desvio padrão intra-cluster:  [31.599032678440523, 30.313924174393932]
#    Dispersão intra-cluster (F_ji):  [41936.95238095238, 108434.21186440677]
#    Dispersão total intra-cluster (F_in): 150371.16424535913
#    Dissimilaridade inter-cluster (F_out): 103240.58693093252
# Clusters: 3
#    Número de elementos (n_j):  [34, 100, 26]
#    Baricentro (m_j):  (array([49.26271186, 44.76271186]), array([78.        , 17.61538462]))
#    Diâmetro do cluster:  [68.46897107449476, 96.0260381354974, 68.15423684555495]
#    Variância intra-cluster:  [363.29152249134944, 695.2379, 452.3801775147929]
#    Desvio padrão intra-cluster:  [19.060207829175145, 26.367364297555415, 21.26923076923077]
#    Dispersão intra-cluster (F_ji):  [12351.911764705881, 69523.79, 11761.884615384615]
#    Dispersão total intra-cluster (F_in): 93637.58638009049
#    Dissimilaridade inter-cluster (F_out): 164283.24879526545
# Clusters: 4
#    Número de elementos (n_j):  [34, 82, 25, 19]
#    Baricentro (m_j):  (array([87.82352941, 82.97058824]), array([26.        , 43.33333333]))
#    Diâmetro do cluster:  [68.46897107449476, 74.33034373659252, 66.61080993352356, 39.05124837953327]
#    Variância intra-cluster:  [363.29152249134944, 453.61823319452697, 445.31200000000007, 156.78116343490302]
#    Desvio padrão intra-cluster:  [19.060207829175145, 21.29831526657747, 21.102416923186787, 12.521228511408257]
#    Dispersão intra-cluster (F_ji):  [12351.911764705881, 37196.69512195121, 11132.800000000001, 2978.8421052631575]
#    Dispersão total intra-cluster (F_in): 63660.248991920256
#    Dissimilaridade inter-cluster (F_out): 170400.20073856643
# Clusters: 5
#    Número de elementos (n_j):  [34, 81, 8, 19, 18]
#    Baricentro (m_j):  (array([43.89, 49.8 ]), array([82.  , 18.75]))
#    Diâmetro do cluster:  [68.46897107449476, 74.33034373659252, 43.41658669218482, 39.05124837953327, 39.05124837953327]
#    Variância intra-cluster:  [363.29152249134944, 452.15393994817873, 267.171875, 156.78116343490302, 186.2716049382716]
#    Desvio padrão intra-cluster:  [19.060207829175145, 21.263911680313637, 16.345393081844193, 12.521228511408257, 13.648135584696966]
#    Dispersão intra-cluster (F_ji):  [12351.911764705881, 36624.46913580248, 2137.375, 2978.8421052631575, 3352.8888888888887]
#    Dispersão total intra-cluster (F_in): 57445.48689466041
#    Dissimilaridade inter-cluster (F_out): 190017.61060496993
# Clusters: 6
#    Número de elementos (n_j):  [24, 81, 8, 19, 18, 10]
#    Baricentro (m_j):  (array([89.30769231, 18.57692308]), array([57.95454545, 57.77272727]))
#    Diâmetro do cluster:  [35.77708763999664, 74.33034373659252, 43.41658669218482, 39.05124837953327, 39.05124837953327, 40.496913462633174]
#    Variância intra-cluster:  [126.94097222222223, 452.15393994817873, 267.171875, 156.78116343490302, 186.2716049382716, 251.20999999999998]
#    Desvio padrão intra-cluster:  [11.266808431060777, 21.263911680313637, 16.345393081844193, 12.521228511408257, 13.648135584696966, 15.849605673328279]
#    Dispersão intra-cluster (F_ji):  [3046.5833333333335, 36624.46913580248, 2137.375, 2978.8421052631575, 3352.8888888888887, 2512.1]
#    Dispersão total intra-cluster (F_in): 50652.258463287864
#    Dissimilaridade inter-cluster (F_out): 216969.1486751591
# Clusters: 7
#    Número de elementos (n_j):  [24, 63, 8, 19, 16, 10, 20]
#    Baricentro (m_j):  (array([87.82352941, 82.97058824]), array([22.6, 43.8]))
#    Diâmetro do cluster:  [35.77708763999664, 42.5440947723653, 43.41658669218482, 39.05124837953327, 35.014282800023196, 40.496913462633174, 39.395431207184416]
#    Variância intra-cluster:  [126.94097222222223, 125.4628369866465, 267.171875, 156.78116343490302, 143.1796875, 251.20999999999998, 224.67500000000004]
#    Desvio padrão intra-cluster:  [11.266808431060777, 11.201019461934994, 16.345393081844193, 12.521228511408257, 11.965771496230404, 15.849605673328279, 14.989162751801718]
#    Dispersão intra-cluster (F_ji):  [3046.5833333333335, 7904.158730158729, 2137.375, 2978.8421052631575, 2290.875, 2512.1, 4493.500000000001]
#    Dispersão total intra-cluster (F_in): 25363.43416875522
#    Dissimilaridade inter-cluster (F_out): 218754.4258849664
# Clusters: 8
#    Número de elementos (n_j):  [24, 62, 8, 12, 10, 20, 16, 8]
#    Baricentro (m_j):  (array([48.43902439, 42.5       ]), array([82.  , 18.75]))
#    Diâmetro do cluster:  [35.77708763999664, 39.44616584663204, 43.41658669218482, 31.240998703626616, 40.496913462633174, 39.395431207184416, 35.014282800023196, 22.80350850198276]
#    Variância intra-cluster:  [126.94097222222223, 120.6402185223725, 267.171875, 98.05555555555556, 251.20999999999998, 224.67500000000004, 143.1796875, 84.46875]
#    Desvio padrão intra-cluster:  [11.266808431060777, 10.983634121836566, 16.345393081844193, 9.902300518341965, 15.849605673328279, 14.989162751801718, 11.965771496230404, 9.1906882223259]
#    Dispersão intra-cluster (F_ji):  [3046.5833333333335, 7479.693548387096, 2137.375, 1176.6666666666667, 2512.1, 4493.500000000001, 2290.875, 675.75]
#    Dispersão total intra-cluster (F_in): 23812.543548387097
#    Dissimilaridade inter-cluster (F_out): 210034.19443297273
# Clusters: 9
#    Número de elementos (n_j):  [20, 62, 8, 12, 4, 20, 16, 8, 10]
#    Baricentro (m_j):  (array([90.04, 17.92]), array([51.61111111, 51.66666667]))
#    Diâmetro do cluster:  [35.77708763999664, 39.44616584663204, 43.41658669218482, 31.240998703626616, 25.298221281347036, 39.395431207184416, 35.014282800023196, 22.80350850198276, 31.064449134018133]
#    Variância intra-cluster:  [112.67749999999998, 120.6402185223725, 267.171875, 98.05555555555556, 116.1875, 224.67500000000004, 143.1796875, 84.46875, 125.89000000000001]
#    Desvio padrão intra-cluster:  [10.61496585015703, 10.983634121836566, 16.345393081844193, 9.902300518341965, 10.779030568655049, 14.989162751801718, 11.965771496230404, 9.1906882223259, 11.22007130102122]
#    Dispersão intra-cluster (F_ji):  [2253.5499999999997, 7479.693548387096, 2137.375, 1176.6666666666667, 464.75, 4493.500000000001, 2290.875, 675.75, 1258.9]
#    Dispersão total intra-cluster (F_in): 22231.060215053763
#    Dissimilaridade inter-cluster (F_out): 225793.21005664679
# Clusters: 10
#    Número de elementos (n_j):  [10, 62, 8, 12, 4, 20, 16, 8, 7, 13]
#    Baricentro (m_j):  (array([25.68421053, 80.52631579]), array([77.8, 76.4]))
#    Diâmetro do cluster:  [20.0, 39.44616584663204, 43.41658669218482, 31.240998703626616, 25.298221281347036, 39.395431207184416, 35.014282800023196, 22.80350850198276, 29.068883707497267, 19.6468827043885]
#    Variância intra-cluster:  [45.96999999999999, 120.6402185223725, 267.171875, 98.05555555555556, 116.1875, 224.67500000000004, 143.1796875, 84.46875, 111.46938775510203, 45.19526627218935]
#    Desvio padrão intra-cluster:  [6.7801179930735715, 10.983634121836566, 16.345393081844193, 9.902300518341965, 10.779030568655049, 14.989162751801718, 11.965771496230404, 9.1906882223259, 10.557906409658216, 6.722742466597196]
#    Dispersão intra-cluster (F_ji):  [459.69999999999993, 7479.693548387096, 2137.375, 1176.6666666666667, 464.75, 4493.500000000001, 2290.875, 675.75, 780.2857142857142, 587.5384615384615]
#    Dispersão total intra-cluster (F_in): 20546.134390877938
#    Dissimilaridade inter-cluster (F_out): 236468.47280941898

# %%
# F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values = calcular_metricas_cluster_kmeans(data_normalized, 10)

# for idx, (F_out, F_in, n_cluster_points, centroid, max_distance, variancia_intra, desvio_padrao_intra) in enumerate(zip(F_out_values, F_in_values, n_cluster_points_values, centroid_values, max_distance_values, variancia_intra_values, desvio_padrao_intra_values)):
#     print(f"Clusters: {idx+1}")
#     print(f"   Número de elementos (n_j): ", n_cluster_points)
#     print(f"   Baricentro (m_j): ", centroid)
#     print(f"   Diâmetro do cluster: ", max_distance)
#     print(f"   Variância intra-cluster: ", variancia_intra)
#     print(f"   Desvio padrão intra-cluster: ", desvio_padrao_intra)
#     print(f"   Dispersão intra-cluster (F_ji): ", F_in)
#     print(f"   Dispersão total intra-cluster (F_in): {sum(F_in)}")
#     print(f"   Dissimilaridade inter-cluster (F_out): {(F_out)}")

# plot_metricas_clusters(F_out_values, F_in_values, max_clusters=10)

# %%
# Testando o valor da heurística maior queda (3) e observação (5)
for optimal_clusters in [3, 4, 5]:
    print(f"Clusters: {optimal_clusters}")
    X_train, X_val = train_test_split(data_normalized, test_size=0.2, random_state=42)
    kmeans = KMeans(n_clusters=optimal_clusters, random_state=0).fit(X_train)
    
    # Obtendo os centróides e rótulos
    m_0 = scaler.inverse_transform(kmeans.cluster_centers_)
    labels = kmeans.labels_

    # Plotando os clusters e seus centróides
    plt.figure(figsize=(8, 5))
    for i in range(optimal_clusters):
        cluster_points = X_train[labels == i]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f"Cluster {i+1}")
    
    plt.scatter(m_0[:, 0], m_0[:, 1], marker='x', s=200, linewidths=2, color='k', label='Centróide')
    plt.title("Clusters de Clientes")
    plt.xlabel("Renda Anual (k$)")
    plt.ylabel("Pontuação de Gastos (1-100)")
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# Clusters: 3
# Clusters: 4
# Clusters: 5

# %% [markdown]
# ## SOM

# %%
# Eu uso topografia linear som
som_shape = (1, int(5*np.sqrt(n_0)))

som = MiniSom(som_shape[0], som_shape[1], data_normalized.shape[1], sigma=0.5, learning_rate=0.5)

max_iter = 1000
q_error = []
t_error = []

for i in range(max_iter):
    rand_i = np.random.randint(len(data_normalized))
    som.update(data_normalized[rand_i], som.winner(data_normalized[rand_i]), i, max_iter)
    q_error.append(som.quantization_error(data_normalized))
    t_error.append(som.topographic_error(data_normalized))

plt.plot(np.arange(max_iter), q_error, label='erro de quantização')
plt.plot(np.arange(max_iter), t_error, label='erro topográfico')
plt.ylabel('Erro de quantização')
plt.xlabel('Índice de iteração')
plt.legend()
plt.show()

# %%
# cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Plotando os clusters 
plt.figure(figsize=(8,5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster='+str(c), alpha=.7)

# Plotando centróides
for centroid in som.get_weights():
    centroid = scaler.inverse_transform(centroid)
    plt.scatter(centroid[:,0], centroid[:, 1], marker='x', 
                s=10, linewidths=20, color='k', label='Centróide') # label='centróide'
    
plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();
plt.plot()

# Supondo que 'som', 'data_normalized', 'som_shape' e 'scaler' já estejam definidos no seu código

# Cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# Com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = data[cluster_index == c]
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(F_j)
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data, cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 3 12 14 17 18 26 33 38 40 41 42 43 46 47 48 49 57]
# F_out (Dispersão inter-cluster): 7270.488523922408
# F_in (Dispersão intra-cluster) por cluster: 13789.327622377623
# Número de pontos por cluster: [1, 2, 1, 16, 6, 13, 7, 3, 14, 48, 12, 10, 10, 14, 33, 8, 2]
# Centróides dos clusters: [array([126.,  28.]), array([102. ,  68.5]), array([137.,  18.]), array([25.375, 74.   ]), array([26.66666667, 93.66666667]), array([77.53846154, 90.84615385]), array([98.71428571, 89.        ]), array([127.66666667,  78.66666667]), array([30.92857143, 35.07142857]), array([52.04166667, 53.66666667]), array([24.58333333,  9.58333333]), array([84.1, 16. ]), array([75.1,  6.6]), array([77.78571429, 73.28571429]), array([63.15151515, 42.72727273]), array([96.625, 25.375]), array([116.5,  12. ])]
# Máxima distância (diâmetro) por cluster: [0.0, 2.23606797749979, 0.0, 28.844410203711913, 20.248456731316587, 18.027756377319946, 25.495097567963924, 17.46424919657298, 28.071337695236398, 31.016124838541646, 21.095023109728988, 17.0, 12.206555615733702, 22.02271554554524, 30.805843601498726, 24.020824298928627, 10.63014581273465]
# Variância intra-cluster por cluster: [0.0, 1.2500000000000002, 0.0, 87.859375, 69.77777777777779, 38.532544378698226, 68.20408163265306, 63.11111111111111, 111.70408163265304, 82.88715277777779, 66.65277777777777, 40.690000000000005, 23.53, 52.65816326530612, 68.56932966023875, 94.21875, 28.250000000000004]
# Desvio padrão intra-cluster por cluster: [0.0, 1.118033988749895, 0.0, 9.373333185158842, 8.353309390761112, 6.207458769794466, 8.258576247311218, 7.944250191875323, 10.569015168531694, 9.104238176683307, 8.164115247703071, 6.378871373526825, 4.850773134253961, 7.256594467469305, 8.280659977335064, 9.706634329158588, 5.315072906367325]

# %%
# removendo neuronios não treinados
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Plotando os clusters 
plt.figure(figsize=(8,5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster='+str(c), alpha=.7)

i=False
for centroid in som.get_weights()[0]:
    # Filtrando centróides próximos de 0
    if centroid[1] > min(data_normalized[:,1]) and centroid[0] > min(data_normalized[:,0]):  # Verifica se qualquer coordenada é maior que a tolerância
        centroid = scaler.inverse_transform([centroid])[0]
        plt.scatter(centroid[0], centroid[1], marker='x', 
                    s=10, linewidths=20, color='k', label='Centróide' if not i else None) # label='centróide'
        i = True
    
plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();
plt.plot()

# Supondo que 'som', 'data_normalized', 'som_shape' e 'scaler' já estejam definidos no seu código

# Cada neurônio representa um cluster
winner_coordinates = np.array([som.winner(x) for x in data_normalized]).T

# Com np.ravel_multi_index, convertemos as coordenadas bidimensionais
# em um índice monodimensional
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)

# Inicializando a lista para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for c in np.unique(cluster_index):
    cluster_points = data_normalized[cluster_index == c]
    
    # Determinando o centróide do cluster (média das coordenadas dos pontos)
    centroid = np.mean(cluster_points, axis=0)
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(float(F_j))
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data_normalized, cluster_index, len(np.unique(cluster_index)))

# Printando as métricas
print("Métricas para os clusters SOM:")
print(f"Clusters: {np.unique(cluster_index)}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {F_j_values}")
print(f"F_in (Dispersão intra-cluster): {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters SOM:
# Clusters: [ 3 12 14 17 18 26 33 38 40 41 42 43 46 47 48 49 57]
# F_out (Dispersão inter-cluster): 0.6408181539025265
# F_in (Dispersão intra-cluster) por cluster: [0.0, 0.0001864341214989134, 0.0, 0.11409756343125416, 0.03172384464757828, 0.040292440460739064, 0.03591808304364803, 0.014222701184966404, 0.11862293767584169, 0.30050014386791196, 0.06507438821718817, 0.032066022499583326, 0.020847134821657343, 0.056432606200750725, 0.1813763686704517, 0.06607669489813267, 0.004978007909228005]
# F_in (Dispersão intra-cluster): 1.0824153716504303
# Número de pontos por cluster: [1, 2, 1, 16, 6, 13, 7, 3, 14, 48, 12, 10, 10, 14, 33, 8, 2]
# Centróides dos clusters: [array([0.90983607, 0.2755102 ]), array([0.71311475, 0.68877551]), array([1.        , 0.17346939]), array([0.08504098, 0.74489796]), array([0.09562842, 0.94557823]), array([0.51261034, 0.91679749]), array([0.68618267, 0.89795918]), array([0.92349727, 0.79251701]), array([0.13056206, 0.34766764]), array([0.30362022, 0.53741497]), array([0.07855191, 0.08758503]), array([0.56639344, 0.15306122]), array([0.49262295, 0.05714286]), array([0.514637  , 0.73760933]), array([0.39468455, 0.4257885 ]), array([0.66905738, 0.24872449]), array([0.83196721, 0.1122449 ])]
# Máxima distância (diâmetro) por cluster: [0.0, 0.019309796555060512, 0.0, 0.25564591639973866, 0.17133672562957067, 0.1478934248895341, 0.2111740566698314, 0.14519915959128052, 0.23041377018340634, 0.2628736296680242, 0.18848094684438277, 0.1475831768998864, 0.11706602397462093, 0.19956198711144044, 0.25606572798506677, 0.24503509269609972, 0.09977983673295929]
# Variância intra-cluster por cluster: [0.0, 9.32170607494567e-05, 0.0, 0.007131097714453385, 0.005287307441263046, 0.003099418496979928, 0.005131154720521148, 0.004740900394988801, 0.008473066976845835, 0.0062604196639148325, 0.005422865684765681, 0.0032066022499583325, 0.002084713482165734, 0.004030900442910766, 0.005496253596074294, 0.008259586862266584, 0.0024890039546140025]
# Desvio padrão intra-cluster por cluster: [0.0, 0.009654898277530256, 0.0, 0.08444582709911358, 0.07271387378804024, 0.05567242133210957, 0.07163207885103676, 0.06885419664035593, 0.09204926385825057, 0.07912281380180329, 0.07364010921207056, 0.056626868622221486, 0.04565866272861848, 0.0634893726769352, 0.07413672231812177, 0.09088226924030113, 0.04988991836647964]

# %%
import numpy as np

# Função para calcular a distância entre dois pontos (centróides)
def calcular_distancia(centroid1, centroid2):
    return np.linalg.norm(centroid1 - centroid2)

# Função para decidir se clusters devem ser agrupados ou bipartidos
def verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points ,threshold=2, population_threshold = 5):
    n_clusters = len(centroid_values)
    agrupamentos = []  # Lista para armazenar decisões de agrupamento
    
    for i in range(n_clusters):
        for j in range(n_clusters):
            if i == j or (i,j) in agrupamentos:
                continue
            # Calcular a distância entre os centróides dos clusters i e j
            dist = calcular_distancia(centroid_values[i], centroid_values[j])

            sigma_sum = sigma_values[i] + sigma_values[j]
            
            # Comparar a distância entre centróides com a soma das dispersões
            if dist < sigma_sum * threshold:  # Se a distância for muito pequena, agrupar
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[j]))  # Armazenar os pares de clusters que devem ser agrupados
                print(f"Clusters {np.unique(cluster_index)[i]} e {np.unique(cluster_index)[j]} podem ser agrupados. Distância: {dist}, Soma das dispersões: {sigma_sum}")
            elif F_values[i] > F_values[j] and F_values[i] > 10 * F_values[j]:  # Se F_k for muito maior em um cluster
                print(f"Cluster {np.unique(cluster_index)[i]} tem alta dispersão (F_k), considerar bipartição.")
    for i in range(n_clusters):
        if n_cluster_points[i] < population_threshold:
            # Encontrar o cluster mais próximo para agrupar
            min_dist = float('inf')
            closest_cluster = None
            for j in range(n_clusters):
                if i != j and n_cluster_points[j] >= population_threshold:  # Não agrupar com clusters de baixa população
                    dist = calcular_distancia(centroid_values[i], centroid_values[j])
                    if dist < min_dist:
                        min_dist = dist
                        closest_cluster = j
            
            if closest_cluster is not None:
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[closest_cluster]))
                print(f"Cluster {np.unique(cluster_index)[i]} tem população baixa e será agrupado com o cluster {np.unique(cluster_index)[closest_cluster]}. Distância: {min_dist}")

        
    
    return agrupamentos

# Exemplo de centróides, dispersões e sigma (desvio padrão)
centroid_values = centroid_values

# Exemplo de dispersão F (somatória da distância intra-cluster)
F_values = F_j_values

# Exemplo de desvio padrão intra-cluster (σ)
sigma_values = desvio_padrao_intra_values

# Chamando a função para verificar agrupamento e bipartição
agrupamentos = verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points_values, 1.5, 9)

# Se necessário, implementar a lógica de bipartição para clusters com alta dispersão F_k
# Out:
# Cluster 12 tem alta dispersão (F_k), considerar bipartição.
# Cluster 12 tem alta dispersão (F_k), considerar bipartição.
# Cluster 17 tem alta dispersão (F_k), considerar bipartição.
# Cluster 17 tem alta dispersão (F_k), considerar bipartição.
# Cluster 17 tem alta dispersão (F_k), considerar bipartição.
# Clusters 17 e 18 podem ser agrupados. Distância: 0.20095936236850068, Soma das dispersões: 0.1571597008871538
# Cluster 17 tem alta dispersão (F_k), considerar bipartição.
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Cluster 18 tem alta dispersão (F_k), considerar bipartição.
# Clusters 18 e 17 podem ser agrupados. Distância: 0.20095936236850068, Soma das dispersões: 0.1571597008871538
# Cluster 26 tem alta dispersão (F_k), considerar bipartição.
# Cluster 26 tem alta dispersão (F_k), considerar bipartição.
# Cluster 26 tem alta dispersão (F_k), considerar bipartição.
# Clusters 26 e 33 podem ser agrupados. Distância: 0.17459162414195917, Soma das dispersões: 0.12730450018314632
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Cluster 33 tem alta dispersão (F_k), considerar bipartição.
# Clusters 33 e 26 podem ser agrupados. Distância: 0.17459162414195917, Soma das dispersões: 0.12730450018314632
# Cluster 38 tem alta dispersão (F_k), considerar bipartição.
# Cluster 38 tem alta dispersão (F_k), considerar bipartição.
# Cluster 38 tem alta dispersão (F_k), considerar bipartição.
# Cluster 40 tem alta dispersão (F_k), considerar bipartição.
# Cluster 40 tem alta dispersão (F_k), considerar bipartição.
# Cluster 40 tem alta dispersão (F_k), considerar bipartição.
# Cluster 40 tem alta dispersão (F_k), considerar bipartição.
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Clusters 41 e 48 podem ser agrupados. Distância: 0.1440596441198056, Soma das dispersões: 0.15325953611992504
# Cluster 41 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 42 tem alta dispersão (F_k), considerar bipartição.
# Cluster 43 tem alta dispersão (F_k), considerar bipartição.
# Cluster 43 tem alta dispersão (F_k), considerar bipartição.
# Cluster 43 tem alta dispersão (F_k), considerar bipartição.
# Clusters 43 e 46 podem ser agrupados. Distância: 0.12100586207039672, Soma das dispersões: 0.10228553135083997
# Clusters 43 e 49 podem ser agrupados. Distância: 0.14032584851303323, Soma das dispersões: 0.14750913786252262
# Cluster 46 tem alta dispersão (F_k), considerar bipartição.
# Cluster 46 tem alta dispersão (F_k), considerar bipartição.
# Cluster 46 tem alta dispersão (F_k), considerar bipartição.
# Clusters 46 e 43 podem ser agrupados. Distância: 0.12100586207039672, Soma das dispersões: 0.10228553135083997
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Cluster 47 tem alta dispersão (F_k), considerar bipartição.
# Cluster 48 tem alta dispersão (F_k), considerar bipartição.
# Cluster 48 tem alta dispersão (F_k), considerar bipartição.
# Cluster 48 tem alta dispersão (F_k), considerar bipartição.
# Cluster 48 tem alta dispersão (F_k), considerar bipartição.
# Clusters 48 e 41 podem ser agrupados. Distância: 0.1440596441198056, Soma das dispersões: 0.15325953611992504
# Cluster 48 tem alta dispersão (F_k), considerar bipartição.
# Cluster 49 tem alta dispersão (F_k), considerar bipartição.
# Cluster 49 tem alta dispersão (F_k), considerar bipartição.
# Cluster 49 tem alta dispersão (F_k), considerar bipartição.
# Clusters 49 e 43 podem ser agrupados. Distância: 0.14032584851303323, Soma das dispersões: 0.14750913786252262
# Cluster 49 tem alta dispersão (F_k), considerar bipartição.
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Cluster 57 tem alta dispersão (F_k), considerar bipartição.
# Cluster 3 tem população baixa e será agrupado com o cluster 43. Distância: 0.36461841404737233
# Cluster 12 tem população baixa e será agrupado com o cluster 47. Distância: 0.20439706417668974
# Cluster 14 tem população baixa e será agrupado com o cluster 43. Distância: 0.434086557875546
# Cluster 18 tem população baixa e será agrupado com o cluster 17. Distância: 0.20095936236850068
# Cluster 33 tem população baixa e será agrupado com o cluster 26. Distância: 0.17459162414195917
# Cluster 38 tem população baixa e será agrupado com o cluster 47. Distância: 0.41253068936757653
# Cluster 49 tem população baixa e será agrupado com o cluster 43. Distância: 0.14032584851303323
# Cluster 57 tem população baixa e será agrupado com o cluster 43. Distância: 0.2686920171584684

# %%
# Agrupando os clusters proximos e com baixa população
for i in agrupamentos:
    cluster_index[cluster_index == i[0]] = i[1]

# Plotando os clusters novamente com os clusters agrupados
plt.figure(figsize=(8, 5))

for c in np.unique(cluster_index):
    plt.scatter(data[cluster_index == c, 0],
                data[cluster_index == c, 1], label='cluster=' + str(c), alpha=.7)

# Plotando centróides
i = False
for centroid in som.get_weights()[0]:
    if centroid[1] > min(data_normalized[:,1]) and centroid[0] > min(data_normalized[:,0]):
        centroid = scaler.inverse_transform([centroid])[0]
        plt.scatter(centroid[0], centroid[1], marker='x', 
                    s=10, linewidths=20, color='k', label='Centróide' if not i else None)
        i = True

plt.title("Clusters de Clientes")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação de Gastos (1-100)")
plt.legend();

# %% [markdown]
# ## ART

# %%
import numpy as np

class ART2:
    def __init__(self, input_dim, num_clusters, vigilance=0.9, learning_rate=0.5):
        self.input_dim = input_dim
        self.num_clusters = num_clusters
        self.vigilance = vigilance
        self.learning_rate = learning_rate
        
        # Inicializar pesos com valores aleatórios
        self.weights = np.random.rand(num_clusters, input_dim)
    
    def normalize(self, vector):
        return vector / (np.linalg.norm(vector) + 1e-9)
    
    def match(self, input_vector, cluster_idx):
        cluster_vector = self.weights[cluster_idx]
        return np.dot(input_vector, cluster_vector) / np.linalg.norm(cluster_vector)
    
    def train(self, data):
        for input_vector in data:
            input_vector = self.normalize(input_vector)
            
            # Testar similaridade com os clusters existentes
            for cluster_idx in range(self.num_clusters):
                similarity = self.match(input_vector, cluster_idx)
                if similarity >= self.vigilance:
                    # Atualizar os pesos do cluster
                    self.weights[cluster_idx] += self.learning_rate * (input_vector - self.weights[cluster_idx])
                    self.weights[cluster_idx] = self.normalize(self.weights[cluster_idx])
                    break
            else:
                print("Nenhum cluster correspondeu ao critério de vigilância.")
    
    def predict(self, data):
        predictions = []
        for input_vector in data:
            input_vector = self.normalize(input_vector)
            similarities = [self.match(input_vector, cluster_idx) for cluster_idx in range(self.num_clusters)]
            predictions.append(np.argmax(similarities))
        return predictions

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Função para calcular a dispersão intra-cluster F_j
def calcular_dispersaointra(cluster_points, centroid):
    return np.sum(np.linalg.norm(cluster_points - centroid, axis=1))

# Função para calcular o diâmetro máximo do cluster
def calcular_diametro(cluster_points):
    distancias = [np.linalg.norm(point1 - point2) 
                  for i, point1 in enumerate(cluster_points) 
                  for j, point2 in enumerate(cluster_points) if i != j]
    return np.max(distancias)

# Função para calcular a variância intra-cluster
def calcular_variancia_intra(cluster_points, centroid):
    return np.var(np.linalg.norm(cluster_points - centroid, axis=1))

# Função para calcular o desvio padrão intra-cluster
def calcular_desvio_padrao_intra(variancia_intra):
    return np.sqrt(variancia_intra)

# Função para calcular a dispersão inter-cluster (F_out)
def calcular_dispersaointer(centroid_values, data_normalized, cluster_index, n_clusters):
    F_out_values = []
    for i in range(n_clusters):
        centroid_i = centroid_values[i]
        distancias = [np.linalg.norm(centroid_i - centroid_values[j]) for j in range(n_clusters) if i != j]
        F_out_values.append(np.mean(distancias))
    return np.mean(F_out_values)

# Inicializando o ART2 com 2 dimensões e 5 clusters
art2 = ART2(input_dim=2, num_clusters=9, vigilance=0.3, learning_rate=0.6)
art2.train(data_normalized)
cluster_assignments = art2.predict(data_normalized)  # Clusters atribuídos

# Plotando os clusters
plt.figure(figsize=(8, 5))

unique_clusters = np.unique(cluster_assignments)
for cluster in unique_clusters:
    cluster_data = data_normalized[np.array(cluster_assignments) == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], 
                label=f'Cluster {cluster + 1}', alpha=0.7)

# Plotando centróides (os pesos dos clusters)
centroids = art2.weights
plt.scatter(centroids[:,0], centroids[:,1], marker='x', 
            s=100, linewidths=2, color='k', label='Centróide')

plt.title("Clusters gerados pela ART 2")
plt.xlabel("Dimensão 1")
plt.ylabel("Dimensão 2")
plt.legend()
plt.show()

# Inicializando as listas para armazenar as métricas de cada cluster
F_j_values = []
max_distance_values = []
variancia_intra_values = []
desvio_padrao_intra_values = []
n_cluster_points_values = []
centroid_values = []

# Calculando as métricas para cada cluster
for cluster in unique_clusters:
    cluster_points = data_normalized[cluster_assignments == cluster]
    
    # Determinando o centróide do cluster (peso do cluster)
    centroid = art2.weights[cluster]
    centroid_values.append(centroid)
    
    # Número de pontos no cluster
    n_cluster_points_values.append(len(cluster_points))
    
    # Calcular a dispersão intra-cluster F_j
    F_j = calcular_dispersaointra(cluster_points, centroid)
    F_j_values.append(float(F_j))
    
    # Calcular o diâmetro máximo do cluster
    max_distance = calcular_diametro(cluster_points)
    max_distance_values.append(float(max_distance))
    
    # Calcular a variância intra-cluster
    variancia_intra = calcular_variancia_intra(cluster_points, centroid)
    variancia_intra_values.append(float(variancia_intra))
    
    # Calcular o desvio padrão intra-cluster
    desvio_padrao_intra = calcular_desvio_padrao_intra(variancia_intra)
    desvio_padrao_intra_values.append(float(desvio_padrao_intra))

# Calculando a dispersão inter-cluster (F_out)
F_out = calcular_dispersaointer(centroid_values, data_normalized, cluster_assignments, len(unique_clusters))

# Printando as métricas
print("Métricas para os clusters ART:")
print(f"Clusters: {unique_clusters}")
print(f"F_out (Dispersão inter-cluster): {F_out}")
print(f"F_in (Dispersão intra-cluster) por cluster: {F_j_values}")
print(f"F_in (Dispersão intra-cluster): {sum(F_j_values)}")
print(f"Número de pontos por cluster: {n_cluster_points_values}")
print(f"Centróides dos clusters: {centroid_values}")
print(f"Máxima distância (diâmetro) por cluster: {max_distance_values}")
print(f"Variância intra-cluster por cluster: {variancia_intra_values}")
print(f"Desvio padrão intra-cluster por cluster: {desvio_padrao_intra_values}")
# Out:
# Métricas para os clusters ART:
# Clusters: [0 1 2 3 4 5 6 7 8]
# F_out (Dispersão inter-cluster): 0.46485266333382913
# F_in (Dispersão intra-cluster) por cluster: [2.012328869760933, 1.6293049977467546, 20.518768939290553, 5.798803668848691, 2.5275913627224336, 6.8725532329090475, 18.70421958862134, 1.449300081247081, 1.702137808780875]
# F_in (Dispersão intra-cluster): 61.21500854992771
# Número de pontos por cluster: [4, 5, 68, 24, 8, 25, 52, 10, 4]
# Centróides dos clusters: [array([0.85160394, 0.52418578]), array([0.76860653, 0.56129138]), array([0.37235707, 0.85176015]), array([0.756541  , 0.09968448]), array([0.18032692, 0.6565926 ]), array([0.08766957, 0.52947794]), array([0.70958947, 0.69722602]), array([0.56612792, 0.28600496]), array([0.7404341 , 0.69453051])]
# Máxima distância (diâmetro) por cluster: [0.751622053347896, 0.6020899664814803, 1.0655654327184456, 0.888607578168841, 0.6478168871766763, 0.9492981311921651, 1.0501273849583797, 0.6652045017034816, 1.1056298295857778]
# Variância intra-cluster por cluster: [0.0782364436325171, 0.0028207511993962424, 0.01823454339331304, 0.01869625827972037, 0.04624004836801404, 0.012216274085388246, 0.02603580113259746, 0.019327424787746923, 0.06047963323279154]
# Desvio padrão intra-cluster por cluster: [0.2797077825740948, 0.053110744669946426, 0.13503534127521225, 0.13673426154303964, 0.21503499335692794, 0.11052725494369361, 0.16135613137590235, 0.13902310882636354, 0.24592607269826341]

# %%
import numpy as np
cluster_index = [i+1 for i in cluster_assignments]
# Função para calcular a distância entre dois pontos (centróides)
def calcular_distancia(centroid1, centroid2):
    return np.linalg.norm(centroid1 - centroid2)

# Função para decidir se clusters devem ser agrupados ou bipartidos
def verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points ,threshold=2, population_threshold = 5):
    n_clusters = len(centroid_values)
    agrupamentos = []  # Lista para armazenar decisões de agrupamento
    
    for i in range(n_clusters):
        for j in range(n_clusters):
            if i == j or (i,j) in agrupamentos:
                continue
            # Calcular a distância entre os centróides dos clusters i e j
            dist = calcular_distancia(centroid_values[i], centroid_values[j])

            sigma_sum = sigma_values[i] + sigma_values[j]
            
            # Comparar a distância entre centróides com a soma das dispersões
            if dist < sigma_sum * threshold:  # Se a distância for muito pequena, agrupar
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[j]))  # Armazenar os pares de clusters que devem ser agrupados
                print(f"Clusters {np.unique(cluster_index)[i]} e {np.unique(cluster_index)[j]} podem ser agrupados. Distância: {dist}, Soma das dispersões: {sigma_sum}")
            elif F_values[i] > F_values[j] and F_values[i] > 10 * F_values[j]:  # Se F_k for muito maior em um cluster
                print(f"Cluster {np.unique(cluster_index)[i]} tem alta dispersão (F_k), considerar bipartição.")
    for i in range(n_clusters):
        if n_cluster_points[i] < population_threshold:
            # Encontrar o cluster mais próximo para agrupar
            min_dist = float('inf')
            closest_cluster = None
            for j in range(n_clusters):
                if i != j and n_cluster_points[j] >= population_threshold:  # Não agrupar com clusters de baixa população
                    dist = calcular_distancia(centroid_values[i], centroid_values[j])
                    if dist < min_dist:
                        min_dist = dist
                        closest_cluster = j
            
            if closest_cluster is not None:
                agrupamentos.append((np.unique(cluster_index)[i], np.unique(cluster_index)[closest_cluster]))
                print(f"Cluster {np.unique(cluster_index)[i]} tem população baixa e será agrupado com o cluster {np.unique(cluster_index)[closest_cluster]}. Distância: {min_dist}")

        
    
    return agrupamentos

# Exemplo de centróides, dispersões e sigma (desvio padrão)
centroid_values = centroid_values

# Exemplo de dispersão F (somatória da distância intra-cluster)
F_values = F_j_values

# Exemplo de desvio padrão intra-cluster (σ)
sigma_values = desvio_padrao_intra_values

# Chamando a função para verificar agrupamento e bipartição
agrupamentos = verificar_agrupamento_biparticao(centroid_values, F_values, sigma_values, n_cluster_points_values, 1.5, 9)

# Se necessário, implementar a lógica de bipartição para clusters com alta dispersão F_k
# Out:
# Clusters 1 e 2 podem ser agrupados. Distância: 0.09091421931534582, Soma das dispersões: 0.3328185272440412
# Clusters 1 e 3 podem ser agrupados. Distância: 0.5805019647692253, Soma das dispersões: 0.414743123849307
# Clusters 1 e 4 podem ser agrupados. Distância: 0.43501530258711635, Soma das dispersões: 0.4164420441171344
# Clusters 1 e 5 podem ser agrupados. Distância: 0.6842107904781976, Soma das dispersões: 0.4947427759310227
# Clusters 1 e 7 podem ser agrupados. Distância: 0.22385494460373295, Soma das dispersões: 0.4410639139499971
# Clusters 1 e 8 podem ser agrupados. Distância: 0.37178845662310567, Soma das dispersões: 0.4187308914004583
# Clusters 1 e 9 podem ser agrupados. Distância: 0.20341106423860503, Soma das dispersões: 0.5256338552723582
# Clusters 2 e 1 podem ser agrupados. Distância: 0.09091421931534582, Soma das dispersões: 0.3328185272440412
# Clusters 2 e 7 podem ser agrupados. Distância: 0.14819325474971212, Soma das dispersões: 0.21446687604584877
# Clusters 3 e 1 podem ser agrupados. Distância: 0.5805019647692253, Soma das dispersões: 0.414743123849307
# Clusters 3 e 5 podem ser agrupados. Distância: 0.2737991057970981, Soma das dispersões: 0.3500703346321402
# Clusters 3 e 7 podem ser agrupados. Distância: 0.3709534839294013, Soma das dispersões: 0.2963914726511146
# Clusters 3 e 9 podem ser agrupados. Distância: 0.4002522436671521, Soma das dispersões: 0.38096141397347566
# Clusters 4 e 1 podem ser agrupados. Distância: 0.43501530258711635, Soma das dispersões: 0.4164420441171344
# Clusters 5 e 1 podem ser agrupados. Distância: 0.6842107904781976, Soma das dispersões: 0.4947427759310227
# Clusters 5 e 3 podem ser agrupados. Distância: 0.2737991057970981, Soma das dispersões: 0.3500703346321402
# Clusters 5 e 6 podem ser agrupados. Distância: 0.1573007302667461, Soma das dispersões: 0.3255622483006215
# Clusters 5 e 7 podem ser agrupados. Distância: 0.5308200463298998, Soma das dispersões: 0.3763911247328303
# Clusters 5 e 9 podem ser agrupados. Distância: 0.5613905387059878, Soma das dispersões: 0.4609610660551914
# Clusters 6 e 5 podem ser agrupados. Distância: 0.1573007302667461, Soma das dispersões: 0.3255622483006215
# Clusters 7 e 1 podem ser agrupados. Distância: 0.22385494460373295, Soma das dispersões: 0.4410639139499971
# Clusters 7 e 2 podem ser agrupados. Distância: 0.14819325474971212, Soma das dispersões: 0.21446687604584877
# Clusters 7 e 3 podem ser agrupados. Distância: 0.3709534839294013, Soma das dispersões: 0.2963914726511146
# Clusters 7 e 5 podem ser agrupados. Distância: 0.5308200463298998, Soma das dispersões: 0.3763911247328303
# Clusters 7 e 8 podem ser agrupados. Distância: 0.435527236773956, Soma das dispersões: 0.3003792402022659
# Clusters 7 e 9 podem ser agrupados. Distância: 0.030962185808183513, Soma das dispersões: 0.40728220407416577
# Clusters 8 e 1 podem ser agrupados. Distância: 0.37178845662310567, Soma das dispersões: 0.4187308914004583
# Clusters 8 e 7 podem ser agrupados. Distância: 0.435527236773956, Soma das dispersões: 0.3003792402022659
# Clusters 9 e 1 podem ser agrupados. Distância: 0.20341106423860503, Soma das dispersões: 0.5256338552723582
# Clusters 9 e 3 podem ser agrupados. Distância: 0.4002522436671521, Soma das dispersões: 0.38096141397347566
# Clusters 9 e 5 podem ser agrupados. Distância: 0.5613905387059878, Soma das dispersões: 0.4609610660551914
# Clusters 9 e 7 podem ser agrupados. Distância: 0.030962185808183513, Soma das dispersões: 0.40728220407416577
# Cluster 1 tem população baixa e será agrupado com o cluster 7. Distância: 0.22385494460373295
# Cluster 2 tem população baixa e será agrupado com o cluster 7. Distância: 0.14819325474971212
# Cluster 5 tem população baixa e será agrupado com o cluster 6. Distância: 0.1573007302667461
# Cluster 9 tem população baixa e será agrupado com o cluster 7. Distância: 0.030962185808183513

# %%
for (i, j) in agrupamentos:
        # Atualizar o índice de cluster para todos os pontos nos clusters i e j
        cluster_assignments[cluster_assignments == int(i)] = j

unique_clusters = np.unique(cluster_assignments)
for cluster in unique_clusters:
    cluster_data = data_normalized[np.array(cluster_assignments) == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], 
                label=f'Cluster {cluster + 1}', alpha=0.7)

# Plotando centróides (os pesos dos clusters)
centroids = art2.weights
plt.scatter(centroids[:,0], centroids[:,1], marker='x', 
            s=100, linewidths=2, color='k', label='Centróide')

plt.title("Clusters gerados pela ART 2")
plt.xlabel("Dimensão 1")
plt.ylabel("Dimensão 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Resultado Final
# Aqui podemos ver que existem 5 clusters de clientes com base na renda anual e na pontuação de gastos:
#
# Cluster 0: Alta renda, baixo gasto
#
# Cluster 1: Alta renda, alto gasto
#
# Cluster 2: Baixa renda, alto gasto
#
# Cluster 3: Renda média, gasto médio
#
# Cluster 4: Baixa renda, baixo gasto
